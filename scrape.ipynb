# %%
import numpy as py
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

import requests
import re
from bs4 import BeautifulSoup

import statistics
from statistics import mode

# %%
##Creating characters_df dataframe from movie_characters_metadata.tsv

column_names = ['character_id', 'character_name', 'movie_id', 'movie_name', 'character_gender', 'position_credits']
characters_df = pd.read_csv('dataset/movie_characters_metadata.tsv', sep='\t', header=None, names=column_names, on_bad_lines='skip')
print("SUCESS : 'characters_df' dataframe created from 'movie_characters_metadata.tsv'\n")
print('Here is a snapshot of data')
characters_df.head()
# Out:
# SUCESS : 'characters_df' dataframe created from 'movie_characters_metadata.tsv'
#
# Here is a snapshot of data
#   character_id character_name movie_id                  movie_name  \
# 0           u0         BIANCA       m0  10 things i hate about you
# 1           u1          BRUCE       m0  10 things i hate about you
# 2           u2        CAMERON       m0  10 things i hate about you
# 3           u3       CHASTITY       m0  10 things i hate about you
# 4           u4           JOEY       m0  10 things i hate about you
#
#   character_gender position_credits
# 0                f                4
# 1                ?                ?
# 2                m                3
# 3                ?                ?
# 4                m                6

# %%
##Creating the dataframe : titles_df

column_names = ['movie_id', 'movie_name', 'movie_year', 'movie_rating', 'movie_votes', 'movie_genre']
titles_df = pd.read_csv('dataset/movie_titles_metadata.tsv', sep='\t', names=column_names, header=None, on_bad_lines='skip')
print("SUCESS : 'titles_df' dataframe created from 'movie_titles_metadata.tsv'\n")
print('Here is a snapshot of data')
titles_df.head()
# Out:
# SUCESS : 'titles_df' dataframe created from 'movie_titles_metadata.tsv'
#
# Here is a snapshot of data
#   movie_id                  movie_name movie_year  movie_rating  movie_votes  \
# 0       m0  10 things i hate about you       1999           6.9      62847.0
# 1       m1  1492: conquest of paradise       1992           6.2      10421.0
# 2       m2                  15 minutes       2001           6.1      25854.0
# 3       m3       2001: a space odyssey       1968           8.4     163227.0
# 4       m4                     48 hrs.       1982           6.9      22289.0
#
#                                       movie_genre
# 0                            ['comedy' 'romance']
# 1     ['adventure' 'biography' 'drama' 'history']
# 2           ['action' 'crime' 'drama' 'thriller']
# 3                ['adventure' 'mystery' 'sci-fi']
# 4  ['action' 'comedy' 'crime' 'drama' 'thriller']

# %%
column_names = ['line_id', 'character_id', 'movie_id', 'character_name', 'character_line']
lines_df = pd.read_csv('dataset/movie_lines.tsv', sep='\t', header=None,names=column_names, on_bad_lines='skip')
print("SUCESS : 'lines_df' dataframe created from 'movie_lines.tsv'\n")
print('Here is a snapshot of data')
lines_df.head()
# Out:
# SUCESS : 'lines_df' dataframe created from 'movie_lines.tsv'
#
# Here is a snapshot of data
#   line_id character_id movie_id character_name character_line
# 0   L1045           u0       m0         BIANCA   They do not!
# 1   L1044           u2       m0        CAMERON    They do to!
# 2    L985           u0       m0         BIANCA     I hope so.
# 3    L984           u2       m0        CAMERON      She okay?
# 4    L925           u0       m0         BIANCA      Let's go.

# %%
column_names = ['character_id1', 'character_id2','movie_id', 'line_list']
conversations_df = pd.read_csv('dataset/movie_conversations.tsv', sep='\t',names=column_names, header=None, on_bad_lines='skip')
print("SUCESS : 'conversations_df' dataframe created from 'movie_conversations.tsv'\n")
print('Here is a snapshot of data')
conversations_df.head()
# Out:
# SUCESS : 'conversations_df' dataframe created from 'movie_conversations.tsv'
#
# Here is a snapshot of data
#   character_id1 character_id2 movie_id                      line_list
# 0            u0            u2       m0  ['L194' 'L195' 'L196' 'L197']
# 1            u0            u2       m0                ['L198' 'L199']
# 2            u0            u2       m0  ['L200' 'L201' 'L202' 'L203']
# 3            u0            u2       m0         ['L204' 'L205' 'L206']
# 4            u0            u2       m0                ['L207' 'L208']

# %%
column_names = ['movie_id','movie_name','url']
raw_script_df = pd.read_csv('dataset/raw_script_urls.tsv', sep='\t', names=column_names, header=None, on_bad_lines='skip')
raw_script_df.head()
# Out:
#   movie_id                  movie_name  \
# 0       m0  10 things i hate about you
# 1       m1  1492: conquest of paradise
# 2       m2                  15 minutes
# 3       m3       2001: a space odyssey
# 4       m4                     48 hrs.
#
#                                                  url
# 0   http://www.dailyscript.com/scripts/10Things.html
# 1  http://www.hundland.org/scripts/1492-ConquestO...
# 2  http://www.dailyscript.com/scripts/15minutes.html
# 3       http://www.scifiscripts.com/scripts/2001.txt
# 4      http://www.awesomefilm.com/script/48hours.txt

# %%
imdb_movie_title_df = pd.read_csv('title.basics.tsv.gz', sep='\t', on_bad_lines='skip', compression='gzip')
imdb_movie_title_df.head()
# Out:
#       tconst titleType            primaryTitle           originalTitle  \
# 0  tt0000001     short              Carmencita              Carmencita
# 1  tt0000002     short  Le clown et ses chiens  Le clown et ses chiens
# 2  tt0000003     short          Pauvre Pierrot          Pauvre Pierrot
# 3  tt0000004     short             Un bon bock             Un bon bock
# 4  tt0000005     short        Blacksmith Scene        Blacksmith Scene
#
#   isAdult startYear endYear runtimeMinutes                    genres
# 0       0      1894      \N              1         Documentary,Short
# 1       0      1892      \N              5           Animation,Short
# 2       0      1892      \N              4  Animation,Comedy,Romance
# 3       0      1892      \N             12           Animation,Short
# 4       0      1893      \N              1              Comedy,Short

# %%
imdb_movie_title_df.titleType.value_counts()
# Out:
# tvEpisode       7891391
# short            963402
# movie            664012
# video            283104
# tvSeries         252641
# tvMovie          143534
# tvMiniSeries      51256
# tvSpecial         44478
# videoGame         36571
# tvShort           10078
# tvPilot               1
# Name: titleType, dtype: int64

# %%
imdb_movie_title_df = imdb_movie_title_df[imdb_movie_title_df.titleType == 'movie']

# %%
imdb_movie_crew_df = pd.read_csv('title.crew.tsv.gz', sep='\t', on_bad_lines='skip', compression='gzip')
imdb_movie_crew_df.head()
# Out:
#       tconst  directors writers
# 0  tt0000001  nm0005690      \N
# 1  tt0000002  nm0721526      \N
# 2  tt0000003  nm0721526      \N
# 3  tt0000004  nm0721526      \N
# 4  tt0000005  nm0005690      \N

# %%
imdb_crew_name_df = pd.read_csv('name.basics.tsv.gz', sep='\t', on_bad_lines='skip', compression='gzip')
imdb_crew_name_df.head()
# Out:
#       nconst      primaryName birthYear deathYear  \
# 0  nm0000001     Fred Astaire      1899      1987
# 1  nm0000002    Lauren Bacall      1924      2014
# 2  nm0000003  Brigitte Bardot      1934        \N
# 3  nm0000004     John Belushi      1949      1982
# 4  nm0000005   Ingmar Bergman      1918      2007
#
#                      primaryProfession  \
# 0       soundtrack,actor,miscellaneous
# 1                   actress,soundtrack
# 2  actress,soundtrack,music_department
# 3              actor,soundtrack,writer
# 4                writer,director,actor
#
#                             knownForTitles
# 0  tt0050419,tt0031983,tt0053137,tt0072308
# 1  tt0038355,tt0117057,tt0037382,tt0075213
# 2  tt0056404,tt0054452,tt0049189,tt0057345
# 3  tt0077975,tt0080455,tt0072562,tt0078723
# 4  tt0069467,tt0083922,tt0050986,tt0050976

# %%
(titles_df['movie_name'].str.upper()).isin(imdb_movie_title_df['primaryTitle'].str.upper()).value_counts()
# Out:
# True     575
# False     42
# Name: movie_name, dtype: int64

# %%
imdb_df = imdb_movie_title_df.merge(imdb_movie_crew_df, on='tconst', how='left').merge(imdb_crew_name_df, left_on='directors', right_on='nconst', how='left')

imdb_df.head()
# Out:
#       tconst titleType                   primaryTitle  \
# 0  tt0000009     movie                     Miss Jerry
# 1  tt0000147     movie  The Corbett-Fitzsimmons Fight
# 2  tt0000502     movie                       Bohemios
# 3  tt0000574     movie    The Story of the Kelly Gang
# 4  tt0000591     movie               The Prodigal Son
#
#                    originalTitle isAdult startYear endYear runtimeMinutes  \
# 0                     Miss Jerry       0      1894      \N             45
# 1  The Corbett-Fitzsimmons Fight       0      1897      \N            100
# 2                       Bohemios       0      1905      \N            100
# 3    The Story of the Kelly Gang       0      1906      \N             70
# 4              L'enfant prodigue       0      1907      \N             90
#
#                        genres  directors                        writers  \
# 0                     Romance  nm0085156                      nm0085156
# 1      Documentary,News,Sport  nm0714557                             \N
# 2                          \N  nm0063413  nm0063413,nm0657268,nm0675388
# 3  Action,Adventure,Biography  nm0846879                      nm0846879
# 4                       Drama  nm0141150                      nm0141150
#
#       nconst       primaryName birthYear deathYear  \
# 0  nm0085156   Alexander Black      1859      1940
# 1  nm0714557   Enoch J. Rector      1863      1957
# 2  nm0063413  Ricardo de Baños      1884      1939
# 3  nm0846879      Charles Tait      1868      1933
# 4  nm0141150      Michel Carré      1865      1945
#
#                  primaryProfession                           knownForTitles
# 0  director,writer,cinematographer                                tt0000009
# 1  director,cinematographer,editor                      tt0000147,tt0381108
# 2  director,cinematographer,writer  tt0000941,tt0004406,tt0002886,tt0024495
# 3                  director,writer                                tt0000574
# 4            director,writer,actor  tt0433554,tt0433594,tt0000591,tt0431913

# %%
titles_df['movie_name_upper'] = titles_df['movie_name'].str.upper()
imdb_df['primaryTitle_upper'] = imdb_df['primaryTitle'].str.upper()

# %%
imdb_df.loc[imdb_df['primaryTitle_upper'] == '10 THINGS I HATE ABOUT YOU']
# Out:
#           tconst titleType                primaryTitle  \
# 95513  tt0147800     movie  10 Things I Hate About You
#
#                     originalTitle isAdult startYear endYear runtimeMinutes  \
# 95513  10 Things I Hate About You       0      1999      \N             97
#
#                      genres  directors                        writers  \
# 95513  Comedy,Drama,Romance  nm0432627  nm0527581,nm0809006,nm0000636
#
#           nconst primaryName birthYear deathYear  \
# 95513  nm0432627  Gil Junger        \N        \N
#
#                      primaryProfession  \
# 95513  producer,director,miscellaneous
#
#                                 knownForTitles          primaryTitle_upper
# 95513  tt5929654,tt0147800,tt0265087,tt0108761  10 THINGS I HATE ABOUT YOU

# %%
titles_df.head()
# Out:
#   movie_id                  movie_name movie_year  movie_rating  movie_votes  \
# 0       m0  10 things i hate about you       1999           6.9      62847.0
# 1       m1  1492: conquest of paradise       1992           6.2      10421.0
# 2       m2                  15 minutes       2001           6.1      25854.0
# 3       m3       2001: a space odyssey       1968           8.4     163227.0
# 4       m4                     48 hrs.       1982           6.9      22289.0
#
#                                       movie_genre            movie_name_upper
# 0                            ['comedy' 'romance']  10 THINGS I HATE ABOUT YOU
# 1     ['adventure' 'biography' 'drama' 'history']  1492: CONQUEST OF PARADISE
# 2           ['action' 'crime' 'drama' 'thriller']                  15 MINUTES
# 3                ['adventure' 'mystery' 'sci-fi']       2001: A SPACE ODYSSEY
# 4  ['action' 'comedy' 'crime' 'drama' 'thriller']                     48 HRS.

# %%
imdb_df.head()
# Out:
#       tconst titleType                   primaryTitle  \
# 0  tt0000009     movie                     Miss Jerry
# 1  tt0000147     movie  The Corbett-Fitzsimmons Fight
# 2  tt0000502     movie                       Bohemios
# 3  tt0000574     movie    The Story of the Kelly Gang
# 4  tt0000591     movie               The Prodigal Son
#
#                    originalTitle isAdult startYear endYear runtimeMinutes  \
# 0                     Miss Jerry       0      1894      \N             45
# 1  The Corbett-Fitzsimmons Fight       0      1897      \N            100
# 2                       Bohemios       0      1905      \N            100
# 3    The Story of the Kelly Gang       0      1906      \N             70
# 4              L'enfant prodigue       0      1907      \N             90
#
#                        genres  directors                        writers  \
# 0                     Romance  nm0085156                      nm0085156
# 1      Documentary,News,Sport  nm0714557                             \N
# 2                          \N  nm0063413  nm0063413,nm0657268,nm0675388
# 3  Action,Adventure,Biography  nm0846879                      nm0846879
# 4                       Drama  nm0141150                      nm0141150
#
#       nconst       primaryName birthYear deathYear  \
# 0  nm0085156   Alexander Black      1859      1940
# 1  nm0714557   Enoch J. Rector      1863      1957
# 2  nm0063413  Ricardo de Baños      1884      1939
# 3  nm0846879      Charles Tait      1868      1933
# 4  nm0141150      Michel Carré      1865      1945
#
#                  primaryProfession                           knownForTitles  \
# 0  director,writer,cinematographer                                tt0000009
# 1  director,cinematographer,editor                      tt0000147,tt0381108
# 2  director,cinematographer,writer  tt0000941,tt0004406,tt0002886,tt0024495
# 3                  director,writer                                tt0000574
# 4            director,writer,actor  tt0433554,tt0433594,tt0000591,tt0431913
#
#               primaryTitle_upper
# 0                     MISS JERRY
# 1  THE CORBETT-FITZSIMMONS FIGHT
# 2                       BOHEMIOS
# 3    THE STORY OF THE KELLY GANG
# 4               THE PRODIGAL SON

# %%
titles_df['movie_name_upper'].isin(imdb_df['primaryTitle_upper']).value_counts()
# Out:
# True     575
# False     42
# Name: movie_name_upper, dtype: int64

# %%
movie_titles_directors_df = titles_df.merge(imdb_df, left_on=['movie_name_upper', 'movie_year'], right_on=['primaryTitle_upper', 'startYear'], how='left')[['movie_id', 'movie_name', 'movie_year', 'movie_rating', 'movie_genre', 'primaryName']]
movie_titles_directors_df.columns = ['movie_id', 'movie_name', 'movie_year', 'movie_rating', 'movie_genre', 'director_name']
movie_titles_directors_df.head(20)
# Out:
#    movie_id                                     movie_name movie_year  \
# 0        m0                     10 things i hate about you       1999
# 1        m1                     1492: conquest of paradise       1992
# 2        m2                                     15 minutes       2001
# 3        m3                          2001: a space odyssey       1968
# 4        m4                                        48 hrs.       1982
# 5        m5                              the fifth element       1997
# 6        m6                                            8mm       1999
# 7        m7  a nightmare on elm street 4: the dream master       1988
# 8        m8     a nightmare on elm street: the dream child       1989
# 9        m9                           the atomic submarine       1959
# 10      m10                                     affliction       1997
# 11      m11                                  air force one       1997
# 12      m12                        airplane ii: the sequel       1982
# 13      m13                                      airplane!       1980
# 14      m14                                   alien nation       1988
# 15      m15                                         aliens       1986
# 16      m16                                        amadeus       1984
# 17      m17                 an american werewolf in london       1981
# 18      m18                               american madness       1932
# 19      m19                               american outlaws       2001
#
#     movie_rating                                        movie_genre  \
# 0            6.9                               ['comedy' 'romance']
# 1            6.2        ['adventure' 'biography' 'drama' 'history']
# 2            6.1              ['action' 'crime' 'drama' 'thriller']
# 3            8.4                   ['adventure' 'mystery' 'sci-fi']
# 4            6.9     ['action' 'comedy' 'crime' 'drama' 'thriller']
# 5            7.5  ['action' 'adventure' 'romance' 'sci-fi' 'thri...
# 6            6.3                     ['crime' 'mystery' 'thriller']
# 7            5.2                    ['fantasy' 'horror' 'thriller']
# 8            4.7                    ['fantasy' 'horror' 'thriller']
# 9            4.9                              ['sci-fi' 'thriller']
# 10           6.9                     ['drama' 'mystery' 'thriller']
# 11           6.3                      ['action' 'drama' 'thriller']
# 12           5.8                      ['comedy' 'romance' 'sci-fi']
# 13           7.8                               ['comedy' 'romance']
# 14           6.1              ['crime' 'drama' 'sci-fi' 'thriller']
# 15           8.5                     ['action' 'sci-fi' 'thriller']
# 16           8.4                      ['biography' 'drama' 'music']
# 17           7.5                               ['horror' 'romance']
# 18           7.4                                          ['drama']
# 19           5.7                               ['action' 'western']
#
#             director_name
# 0              Gil Junger
# 1            Ridley Scott
# 2           John Herzfeld
# 3         Stanley Kubrick
# 4             Walter Hill
# 5              Luc Besson
# 6         Joel Schumacher
# 7            Renny Harlin
# 8         Stephen Hopkins
# 9   Spencer Gordon Bennet
# 10          Paul Schrader
# 11      Wolfgang Petersen
# 12          Ken Finkleman
# 13                    NaN
# 14           Graham Baker
# 15          James Cameron
# 16           Milos Forman
# 17            John Landis
# 18                    NaN
# 19           Les Mayfield

# %%
movie_titles_directors_df.duplicated().value_counts()
# Out:
# False    617
# dtype: int64

# %%
movie_titles_directors_df['director_gender'] = 'Unknown'
movie_titles_directors_df.head()
# Out:
#   movie_id                  movie_name movie_year  movie_rating  \
# 0       m0  10 things i hate about you       1999           6.9
# 1       m1  1492: conquest of paradise       1992           6.2
# 2       m2                  15 minutes       2001           6.1
# 3       m3       2001: a space odyssey       1968           8.4
# 4       m4                     48 hrs.       1982           6.9
#
#                                       movie_genre    director_name  \
# 0                            ['comedy' 'romance']       Gil Junger
# 1     ['adventure' 'biography' 'drama' 'history']     Ridley Scott
# 2           ['action' 'crime' 'drama' 'thriller']    John Herzfeld
# 3                ['adventure' 'mystery' 'sci-fi']  Stanley Kubrick
# 4  ['action' 'comedy' 'crime' 'drama' 'thriller']      Walter Hill
#
#   director_gender
# 0         Unknown
# 1         Unknown
# 2         Unknown
# 3         Unknown
# 4         Unknown

# %%
movie_titles_directors_df['director_name'].fillna('Unknown', inplace=True)

# %%
def identify_gender(text):
    male_pronouns = ['he', 'him', 'his']
    female_pronouns = ['she', 'her', 'hers']

    words = text.lower().split()

    male_count = len([w for w in words if w in male_pronouns])
    female_count = len([w for w in words if w in female_pronouns])

    if male_count > female_count:
        return 'M'
    elif female_count > male_count:
        return 'F'
    else:
        return 'Unknown'

for index, row in movie_titles_directors_df.iterrows():
	dg=[]
	paragraphs = []
	url = "https://en.wikipedia.org/wiki/" + row['director_name'].replace(" ", "_")
	response = requests.get(url)
	soup = BeautifulSoup(response.content, "html.parser")

	if len(soup.findAll("p")) == 1:
		paragraphs.clear()
		url = "https://en.wikipedia.org/wiki/" + row['director_name'].replace(" ", "_") + "_(director)"
		response = requests.get(url)
		soup = BeautifulSoup(response.content, "html.parser")

	paragraphs = (soup.findAll("p"))

	# print(paragraphs)
	for (i, p) in enumerate(paragraphs):
		if row['director_name'] == "Stephen Hopkins":
			print(identify_gender(p.text))
		dg.append(identify_gender(p.text))

	if 'Unknown' in dg:
		dg = [i for i in dg if i != 'Unknown']

	if len(dg) == 0:
		dg.append('Unknown')

	print(row['director_name'])
	print(mode(dg))
	movie_titles_directors_df.loc[index, 'director_gender'] = mode(dg)
	dg.clear()
# Out:
# Gil Junger
# M
# Ridley Scott
# M
# John Herzfeld
# M
# Stanley Kubrick
# M
# Walter Hill
# M
# Luc Besson
# M
# Joel Schumacher
# M
# Renny Harlin
# M
# M
# M
# M
# Unknown
# M
# M
# Unknown
# Unknown
# M
# Unknown
# Unknown
# Unknown
# Unknown
# Unknown
# Unknown
# Unknown
# Unknown
# Unknown
# Unknown
# Unknown
# Unknown
# Unknown
# Stephen Hopkins
# M
# Spencer Gordon Bennet
# M
# Paul Schrader
# M
# Wolfgang Petersen
# M
# Ken Finkleman
# M
# Unknown
# Unknown
# Graham Baker
# M
# James Cameron
# M
# Milos Forman
# M
# John Landis
# M
# Unknown
# Unknown
# Les Mayfield
# M
# Mary Harron
# F
# Peter Howitt
# M
# Jay Roach
# M
# Jeremiah S. Chechik
# M
# Neal Israel
# M
# Ron Howard
# M
# Abel Ferrara
# M
# Spike Lee
# M
# Stanley Kubrick
# M
# John McTiernan
# M
# Tim Burton
# M
# Jez Butterworth
# M
# Craig Brewer
# M
# Unknown
# Unknown
# Ridley Scott
# M
# Hugh Wilson
# M
# David Lynch
# M
# Troy Duffy
# M
# Wes Anderson
# M
# Paul Greengrass
# M
# Mel Gibson
# M
# Unknown
# Unknown
# Michael Curtiz
# M
# Robert Zemeckis
# M
# Lasse Hallström
# M
# James Foley
# M
# Mike Hodges
# M
# John Carpenter
# M
# Craig R. Baxley
# M
# Adam Rifkin
# M
# Richard Kelly
# M
# Michael Patrick Jann
# M
# Leo McCarey
# M
# David Lynch
# M
# Terry Jones
# M
# Michel Gondry
# M
# Gus Van Sant
# M
# Paul W.S. Anderson
# M
# Tim Story
# M
# Amy Heckerling
# F
# Terry Gilliam
# M
# John Gulager
# M
# Graeme Clifford
# M
# James Whale
# M
# Marcus Nispel
# M
# Robert Rodriguez
# M
# Ridley Scott
# M
# Roland Emmerich
# M
# Dean Parisot
# M
# David Gordon Green
# M
# Barry Sonnenfeld
# M
# Steve Beck
# M
# Terry Zwigoff
# M
# M
# M
# M
# Unknown
# M
# M
# Unknown
# Unknown
# M
# Unknown
# Unknown
# Unknown
# Unknown
# Unknown
# Unknown
# Unknown
# Unknown
# Unknown
# Unknown
# Unknown
# Unknown
# Unknown
# Stephen Hopkins
# M
# Ivan Reitman
# M
# Unknown
# Unknown
# Ridley Scott
# M
# Mike Nichols
# M
# Edmund Goulding
# M
# Stephen Frears
# M
# Steve Miner
# M
# Joe Chappelle
# M
# Unknown
# Unknown
# Paul Schrader
# M
# Hal Ashby
# M
# Tony Randel
# M
# Guillermo del Toro
# M
# Clive Barker
# M
# Stephen Frears
# M
# Russell Mulcahy
# M
# Howard Hawks
# M
# John Boorman
# M
# Rob Zombie
# M
# Michel Gondry
# M
# Robert Rossen
# M
# Francis Lawrence
# M
# William Cameron Menzies
# M
# Roland Emmerich
# M
# Steven Spielberg
# M
# Steven Spielberg
# M
# Joe Dante
# M
# Michael Mann
# M
# Unknown
# Unknown
# Frank Capra
# M
# Oliver Stone
# M
# Quentin Tarantino
# M
# Unknown
# Unknown
# James Isaac
# M
# Steven Spielberg
# M
# Jason Reitman
# M
# Dominic Sena
# M
# Larry Clark
# M
# Carl Schenkel
# M
# Peter Yates
# M
# Unknown
# Unknown
# Unknown
# Unknown
# Mike Figgis
# M
# Robert Luketic
# M
# Ridley Scott
# M
# Irwin Winkler
# M
# Alan Parker
# M
# Steven Brill
# M
# Michael Anderson
# M
# David Lynch
# M
# Frank Capra
# M
# Barry Sonnenfeld
# M
# Steven Spielberg
# M
# Jon Favreau
# M
# Spike Lee
# M
# Tony Scott
# M
# Delbert Mann
# M
# Unknown
# Unknown
# Frank Capra
# M
# Thomas Carter
# M
# Fritz Lang
# M
# Unknown
# Unknown
# Michael Karbelnikoff
# Unknown
# Henry Selick
# M
# Unknown
# Unknown
# Frank Capra
# M
# Frank Capra
# M
# Lawrence Kasdan
# M
# Stephen Sommers
# M
# Kinka Usher
# M
# Mario Andreacchio
# M
# Steve Carr
# M
# John Badham
# M
# Charles Laughton
# M
# Wes Craven
# M
# Ernst Lubitsch
# M
# Oliver Stone
# M
# Unknown
# Unknown
# Neil LaBute
# M
# Unknown
# Unknown
# Taylor Hackford
# M
# David Fincher
# M
# Unknown
# Unknown
# Roland Emmerich
# M
# Mary Lambert
# F
# Unknown
# Unknown
# Unknown
# Unknown
# Frank Capra
# M
# Gary Ross
# M
# Paul Thomas Anderson
# M
# Philip Kaufman
# M
# Unknown
# Unknown
# Martin Scorsese
# M
# Alfred Hitchcock
# M
# Nicholas Ray
# M
# John Frankenheimer
# M
# Quentin Tarantino
# M
# Mark Robson
# Unknown
# Keenen Ivory Wayans
# M
# John Waters
# M
# Mark Robson
# Unknown
# Unknown
# Unknown
# David Cronenberg
# M
# Jim Sharman
# M
# Alexander Payne
# M
# M. Night Shyamalan
# M
# Lawrence Kasdan
# M
# Unknown
# Unknown
# M. Night Shyamalan
# M
# Neal Sundstrom
# Unknown
# James Gunn
# M
# Hal Needham
# M
# Joe Carnahan
# M
# Steven Soderbergh
# M
# Ridley Scott
# M
# Sam Raimi
# M
# Billy Wilder
# M
# David Carson
# M
# Leonard Nimoy
# M
# Unknown
# Unknown
# Leonard Nimoy
# M
# Jonathan Frakes
# M
# Jonathan Frakes
# M
# Nicholas Meyer
# M
# Stuart Baird
# M
# John Carpenter
# M
# Kathryn Bigelow
# F
# E. Elias Merhige
# M
# Doug Liman
# M
# Francis Ford Coppola
# M
# Anthony Minghella
# M
# Martin Scorsese
# M
# Michael Bay
# M
# Frank Darabont
# M
# Alfred Hitchcock
# M
# Robert Wise
# M
# Bharat Nalluri
# M
# Scott Derrickson
# M
# Joel Schumacher
# M
# John Carpenter
# M
# Simon Wells
# M
# John Maybury
# M
# Ridley Scott
# M
# Unknown
# Unknown
# Roger Donaldson
# M
# Michael Apted
# M
# Tony Scott
# M
# Paul Verhoeven
# M
# Ron Underwood
# M
# Joseph Ruben
# M
# David Lynch
# M
# Sidney Lumet
# M
# Byron Haskin
# M
# Wes Craven
# M
# Ridley Scott
# M
# David Lynch
# M
# Curtis Hanson
# M
# Nicole Kassell
# F
# James Cameron
# M
# Michelangelo Antonioni
# M
# Norman Jewison
# M
# Richard Lester
# M
# Ridley Scott
# M
# Unknown
# Unknown
# Joseph L. Mankiewicz
# M
# Alan J. Pakula
# M
# Unknown
# Unknown
# Anthony Waller
# M
# Unknown
# Unknown
# Woody Allen
# M
# Unknown
# Unknown
# Unknown
# Unknown
# Billy Wilder
# M
# Francis Ford Coppola
# M
# Peter Masterson
# M
# James L. Brooks
# M
# Richard Donner
# M
# David Mackenzie
# M
# Adam Shankman
# M
# Robert Zemeckis
# M
# Terrence Malick
# M
# W.D. Richter
# M
# Unknown
# Unknown
# Paul Verhoeven
# M
# Julian Schnabel
# M
# Tim Burton
# M
# Spencer Gordon Bennet
# M
# Joel Schumacher
# M
# Tim Burton
# M
# Mel Smith
# M
# Unknown
# Unknown
# Unknown
# Unknown
# Hal Ashby
# M
# Spike Jonze
# M
# Unknown
# Unknown
# Unknown
# Unknown
# Brian De Palma
# M
# Guillermo del Toro
# M
# Stephen Norrington
# M
# Joe Berlinger
# M
# Unknown
# Unknown
# Siu-Hung Leung
# Unknown
# Ted Demme
# M
# Unknown
# Unknown
# Unknown
# Unknown
# Clint Eastwood
# M
# Ernest R. Dickerson
# M
# Unknown
# Unknown
# Doug Liman
# M
# Terry Gilliam
# M
# Martin Scorsese
# M
# James L. Brooks
# M
# Roger Corman
# M
# Fran Rubel Kuzui
# F
# Ron Shelton
# M
# Martin Scorsese
# M
# Pitof
# M
# David R. Ellis
# M
# Neil Jordan
# M
# Stanley Donen
# M
# Unknown
# Unknown
# Hugh Johnson
# Unknown
# Roman Polanski
# M
# Unknown
# Unknown
# Orson Welles
# M
# Unknown
# Unknown
# Renny Harlin
# M
# Stanley Kubrick
# M
# Michael Mann
# M
# Richard Donner
# M
# Robert Zemeckis
# M
# Stuart Rosenberg
# M
# Jon Amiel
# M
# Unknown
# Unknown
# Unknown
# Unknown
# Brad Mirman
# Unknown
# Unknown
# Unknown
# Alex Proyas
# M
# Roger Kumble
# M
# Unknown
# Unknown
# David Keith
# Unknown
# Alex Proyas
# M
# Ivan Reitman
# M
# George A. Romero
# M
# Peter Weir
# M
# Stephen Sommers
# M
# Michael Cimino
# M
# Marco Brambilla
# M
# Unknown
# Unknown
# John McTiernan
# M
# Sidney Lumet
# M
# Tony Scott
# M
# Spike Lee
# M
# Troy Miller
# Unknown
# David Lynch
# M
# Tim Burton
# M
# Ron Howard
# M
# Alexander Payne
# M
# Curtis Hanson
# M
# Tony Scott
# M
# Anthony Minghella
# M
# Jon Amiel
# M
# Steven Soderbergh
# M
# Unknown
# Unknown
# Don Taylor
# Unknown
# John Carpenter
# M
# John Boorman
# M
# William Friedkin
# M
# Steve Kloves
# M
# John Woo
# M
# Brett Ratner
# M
# Oley Sassone
# Unknown
# Richard Fleischer
# M
# Unknown
# Unknown
# David Fincher
# M
# David R. Ellis
# M
# James Wong
# Unknown
# George P. Cosmatos
# M
# Terry Gilliam
# M
# Bob Rafelson
# M
# Unknown
# Unknown
# Michael Ritchie
# Unknown
# Renny Harlin
# M
# William Friedkin
# M
# Gregory Hoblit
# M
# Unknown
# Unknown
# Unknown
# Unknown
# Unknown
# Unknown
# Rob Hedden
# M
# Michael Hoffman
# M
# Richard Attenborough
# M
# Andrew Niccol
# M
# Sam Peckinpah
# M
# Stephen Kay
# M
# James Foley
# M
# Unknown
# Unknown
# Bill Condon
# M
# Unknown
# Unknown
# Martin Scorsese
# M
# Gus Van Sant
# M
# John Ford
# M
# George Armitage
# M
# Robert Redford
# M
# Iain Softley
# M
# Dwight H. Little
# M
# John Carpenter
# M
# Woody Allen
# M
# Ridley Scott
# M
# Daniel Waters
# Unknown
# Unknown
# Unknown
# Peter Jackson
# M
# Unknown
# Unknown
# Unknown
# Unknown
# Matthew Patrick
# Unknown
# Unknown
# Unknown
# Unknown
# Unknown
# Terry George
# M
# William Malone
# M
# Unknown
# Unknown
# Anthony Hickox
# M
# Michael Lehmann
# M
# Unknown
# Unknown
# Jacques Tourneur
# M
# Ang Lee
# M
# Unknown
# Unknown
# Neil Jordan
# M
# Danny Cannon
# M
# Mark Robson
# Unknown
# Frank Capra
# M
# Jeannot Szwarc
# M
# Joe Alves
# M
# Joseph Sargent
# M
# Alan Crosland
# M
# Unknown
# Unknown
# Cameron Crowe
# M
# Joe Johnston
# M
# Steven Spielberg
# M
# Steven Spielberg
# M
# Ronny Yu
# M
# Steven Soderbergh
# M
# Peter Jackson
# M
# Alan J. Pakula
# M
# Robert Benton
# M
# Martin Scorsese
# M
# Steve Miner
# M
# Jonathan Demme
# M
# Unknown
# Unknown
# George P. Cosmatos
# M
# Unknown
# Unknown
# John Sayles
# M
# Clive Barker
# M
# Sofia Coppola
# F
# Janusz Kaminski
# M
# Gina Prince-Bythewood
# F
# Paul Thomas Anderson
# M
# Unknown
# Unknown
# Unknown
# Unknown
# Michael Mann
# M
# Milos Forman
# M
# Unknown
# Unknown
# Tommy Lee Wallace
# M
# Martin Brest
# M
# Christopher Nolan
# M
# Michael Mann
# M
# John Schlesinger
# M
# Alan Parker
# M
# Guillermo del Toro
# M
# Rob Reiner
# M
# John Woo
# M
# Brian De Palma
# M
# Norman Jewison
# M
# Unknown
# Unknown
# Unknown
# Unknown
# Unknown
# Unknown
# Unknown
# Unknown
# Unknown
# Unknown
# Howard Zieff
# M
# Howard Zieff
# M
# P.J. Hogan
# M
# Robert Altman
# M
# Oliver Stone
# M
# Michael Roemer
# M
# F. Gary Gray
# M
# Unknown
# Unknown
# Raja Gosnell
# M
# Henry Selick
# M
# Unknown
# Unknown
# Chuck Russell
# M
# Roger Michell
# M
# Milos Forman
# M
# Norman Jewison
# M
# Elia Kazan
# M
# Stephen C. Apostolof
# M
# Steven Soderbergh
# M
# Michael Bay
# M
# Francis Ford Coppola
# M
# Mary Lambert
# F
# Jonathan Demme
# M
# David Twohy
# M
# Tim Burton
# M
# Oliver Stone
# M
# Oley Sassone
# Unknown
# Richard Eyre
# M
# Kathryn Bigelow
# F
# John McTiernan
# M
# Garry Marshall
# M
# Rob Reiner
# M
# Unknown
# Unknown
# Alfred Hitchcock
# M
# William Lustig
# M
# Carl Theodor Dreyer
# M
# Michael Curtiz
# M
# Unknown
# Unknown
# Martha Coolidge
# F
# Tom Putnam
# Unknown
# Richard Marquand
# M
# Jim Sharman
# M
# John G. Avildsen
# M
# Robert Zemeckis
# M
# Unknown
# Unknown
# John Frankenheimer
# M
# Unknown
# Unknown
# Brett Ratner
# M
# Brett Ratner
# M
# Garry Marshall
# M
# Nora Ephron
# F
# Herbert J. Biberman
# M
# D.J. Caruso
# M
# Steven Spielberg
# M
# Unknown
# Unknown
# Steven Spielberg
# M
# Wes Craven
# M
# Wes Craven
# M
# Unknown
# Unknown
# Andy Sidaris
# M
# John Ford
# M
# Sebastian Niemann
# Unknown
# John Madden
# M
# Danny Boyle
# M
# Hal Ashby
# M
# Stanley Kubrick
# M
# Daniel Attias
# M
# Emile Ardolino
# M
# Tim Burton
# M
# Billy Bob Thornton
# M
# Wayne Wang
# M
# Scott Hicks
# M
# Unknown
# Unknown
# Billy Wilder
# M
# Clare Kilner
# F
# Martin Ritt
# M
# Unknown
# Unknown
# Unknown
# Unknown
# Unknown
# Unknown
# Barry Levinson
# M
# Unknown
# Unknown
# Paul Verhoeven
# M
# Robert Wise
# M
# David Mamet
# M
# Chris Columbus
# Unknown
# Todd Solondz
# M
# Unknown
# Unknown
# Stanley Kubrick
# M
# Richard Linklater
# M
# Francine McDougall
# F
# Billy Wilder
# M
# Jeannot Szwarc
# M
# Richard Lester
# M
# Unknown
# Unknown
# Sidney J. Furie
# M
# Richard Donner
# M
# Atom Egoyan
# M
# Alexander Mackendrick
# M
# James Cameron
# M
# István Szabó
# M
# James Cameron
# M
# David Fincher
# M
# Jan de Bont
# M
# Steven Soderbergh
# M
# Joel Coen
# M
# Peter Hyams
# M
# Peter Weir
# M
# Rob Bowman
# M
# Tarsem Singh
# M
# Carol Reed
# M
# Unknown
# Unknown
# Henry Bean
# M
# Unknown
# Unknown
# Jonathan Kesselman
# M
# Jacques Tourneur
# M
# Chris Menges
# M
# Unknown
# Unknown
# Roman Polanski
# M
# Jane Campion
# F
# George Roy Hill
# M
# W.S. Van Dyke
# M
# David O. Russell
# M
# George Lucas
# M
# Albert Pyun
# M
# Ernst Lubitsch
# M
# James Cameron
# M
# Benjamin Stoloff
# M
# Unknown
# Unknown
# Roger Spottiswoode
# M
# Charles Burnett
# M
# John Lasseter
# M
# David Wheatley
# M
# Steven Soderbergh
# M
# Danny Boyle
# M
# William Shatner
# M
# Steven Lisberger
# M
# James Cameron
# M
# Tony Scott
# M
# Unknown
# Unknown
# Unknown
# Unknown
# Oliver Stone
# M
# M. Night Shyamalan
# M
# Clint Eastwood
# M
# Bryan Singer
# M
# André Cayatte
# M
# Alfred Hitchcock
# M
# Peter Berg
# M
# Luis Buñuel
# M
# Brett Leonard
# M
# Barry Levinson
# M
# Oliver Stone
# M
# Anthony Hickox
# M
# Robert Zemeckis
# M
# Nancy Meyers
# F
# Unknown
# Unknown
# Chris Jones
# Unknown
# Unknown
# Unknown
# John McNaughton
# M
# Barry Sonnenfeld
# M
# Ron Howard
# M
# Peter Weir
# M
# Unknown
# Unknown
# Michael Apted
# M
# Zack Snyder
# M
# Rob Cohen
# M
# Bryan Singer
# M
# Mel Brooks
# M
# Douglas Hickox
# M

# %%
movie_titles_directors_df.head(20)
# Out:
#    movie_id                                     movie_name movie_year  \
# 0        m0                     10 things i hate about you       1999
# 1        m1                     1492: conquest of paradise       1992
# 2        m2                                     15 minutes       2001
# 3        m3                          2001: a space odyssey       1968
# 4        m4                                        48 hrs.       1982
# 5        m5                              the fifth element       1997
# 6        m6                                            8mm       1999
# 7        m7  a nightmare on elm street 4: the dream master       1988
# 8        m8     a nightmare on elm street: the dream child       1989
# 9        m9                           the atomic submarine       1959
# 10      m10                                     affliction       1997
# 11      m11                                  air force one       1997
# 12      m12                        airplane ii: the sequel       1982
# 13      m13                                      airplane!       1980
# 14      m14                                   alien nation       1988
# 15      m15                                         aliens       1986
# 16      m16                                        amadeus       1984
# 17      m17                 an american werewolf in london       1981
# 18      m18                               american madness       1932
# 19      m19                               american outlaws       2001
#
#     movie_rating                                        movie_genre  \
# 0            6.9                               ['comedy' 'romance']
# 1            6.2        ['adventure' 'biography' 'drama' 'history']
# 2            6.1              ['action' 'crime' 'drama' 'thriller']
# 3            8.4                   ['adventure' 'mystery' 'sci-fi']
# 4            6.9     ['action' 'comedy' 'crime' 'drama' 'thriller']
# 5            7.5  ['action' 'adventure' 'romance' 'sci-fi' 'thri...
# 6            6.3                     ['crime' 'mystery' 'thriller']
# 7            5.2                    ['fantasy' 'horror' 'thriller']
# 8            4.7                    ['fantasy' 'horror' 'thriller']
# 9            4.9                              ['sci-fi' 'thriller']
# 10           6.9                     ['drama' 'mystery' 'thriller']
# 11           6.3                      ['action' 'drama' 'thriller']
# 12           5.8                      ['comedy' 'romance' 'sci-fi']
# 13           7.8                               ['comedy' 'romance']
# 14           6.1              ['crime' 'drama' 'sci-fi' 'thriller']
# 15           8.5                     ['action' 'sci-fi' 'thriller']
# 16           8.4                      ['biography' 'drama' 'music']
# 17           7.5                               ['horror' 'romance']
# 18           7.4                                          ['drama']
# 19           5.7                               ['action' 'western']
#
#             director_name director_gender
# 0              Gil Junger               M
# 1            Ridley Scott               M
# 2           John Herzfeld               M
# 3         Stanley Kubrick               M
# 4             Walter Hill               M
# 5              Luc Besson               M
# 6         Joel Schumacher               M
# 7            Renny Harlin               M
# 8         Stephen Hopkins               M
# 9   Spencer Gordon Bennet               M
# 10          Paul Schrader               M
# 11      Wolfgang Petersen               M
# 12          Ken Finkleman               M
# 13                Unknown         Unknown
# 14           Graham Baker               M
# 15          James Cameron               M
# 16           Milos Forman               M
# 17            John Landis               M
# 18                Unknown         Unknown
# 19           Les Mayfield               M

# %%
movie_titles_directors_df.director_gender.value_counts()
# Out:
# M          484
# Unknown    117
# F           16
# Name: director_gender, dtype: int64

# %%
final_df = movie_titles_directors_df.merge(characters_df, on='movie_id', how='left').merge(lines_df, on=['movie_id', 'character_id'], how='left')
final_df.drop(['movie_name_y', 'character_name_y'], axis=1, inplace=True)
final_df.columns=['movie_id', 'movie_name', 'movie_year',	'movie_rating',	'movie_genre','director_name'	,'director_gender'	,'character_id',	'character_name',	'character_gender',	'position_credits',	'line_id',	'character_line']
final_df.head(20)
# Out:
#    movie_id                  movie_name movie_year  movie_rating  \
# 0        m0  10 things i hate about you       1999           6.9
# 1        m0  10 things i hate about you       1999           6.9
# 2        m0  10 things i hate about you       1999           6.9
# 3        m0  10 things i hate about you       1999           6.9
# 4        m0  10 things i hate about you       1999           6.9
# 5        m0  10 things i hate about you       1999           6.9
# 6        m0  10 things i hate about you       1999           6.9
# 7        m0  10 things i hate about you       1999           6.9
# 8        m0  10 things i hate about you       1999           6.9
# 9        m0  10 things i hate about you       1999           6.9
# 10       m0  10 things i hate about you       1999           6.9
# 11       m0  10 things i hate about you       1999           6.9
# 12       m0  10 things i hate about you       1999           6.9
# 13       m0  10 things i hate about you       1999           6.9
# 14       m0  10 things i hate about you       1999           6.9
# 15       m0  10 things i hate about you       1999           6.9
# 16       m0  10 things i hate about you       1999           6.9
# 17       m0  10 things i hate about you       1999           6.9
# 18       m0  10 things i hate about you       1999           6.9
# 19       m0  10 things i hate about you       1999           6.9
#
#              movie_genre director_name director_gender character_id  \
# 0   ['comedy' 'romance']    Gil Junger               M           u0
# 1   ['comedy' 'romance']    Gil Junger               M           u0
# 2   ['comedy' 'romance']    Gil Junger               M           u0
# 3   ['comedy' 'romance']    Gil Junger               M           u0
# 4   ['comedy' 'romance']    Gil Junger               M           u0
# 5   ['comedy' 'romance']    Gil Junger               M           u0
# 6   ['comedy' 'romance']    Gil Junger               M           u0
# 7   ['comedy' 'romance']    Gil Junger               M           u0
# 8   ['comedy' 'romance']    Gil Junger               M           u0
# 9   ['comedy' 'romance']    Gil Junger               M           u0
# 10  ['comedy' 'romance']    Gil Junger               M           u0
# 11  ['comedy' 'romance']    Gil Junger               M           u0
# 12  ['comedy' 'romance']    Gil Junger               M           u0
# 13  ['comedy' 'romance']    Gil Junger               M           u0
# 14  ['comedy' 'romance']    Gil Junger               M           u0
# 15  ['comedy' 'romance']    Gil Junger               M           u0
# 16  ['comedy' 'romance']    Gil Junger               M           u0
# 17  ['comedy' 'romance']    Gil Junger               M           u0
# 18  ['comedy' 'romance']    Gil Junger               M           u0
# 19  ['comedy' 'romance']    Gil Junger               M           u0
#
#    character_name character_gender position_credits line_id  \
# 0          BIANCA                f                4   L1045
# 1          BIANCA                f                4    L985
# 2          BIANCA                f                4    L925
# 3          BIANCA                f                4    L872
# 4          BIANCA                f                4    L869
# 5          BIANCA                f                4    L867
# 6          BIANCA                f                4    L864
# 7          BIANCA                f                4    L862
# 8          BIANCA                f                4    L698
# 9          BIANCA                f                4    L696
# 10         BIANCA                f                4    L694
# 11         BIANCA                f                4    L663
# 12         BIANCA                f                4    L577
# 13         BIANCA                f                4    L575
# 14         BIANCA                f                4    L407
# 15         BIANCA                f                4    L405
# 16         BIANCA                f                4    L402
# 17         BIANCA                f                4    L368
# 18         BIANCA                f                4    L366
# 19         BIANCA                f                4    L364
#
#                                        character_line
# 0                                        They do not!
# 1                                          I hope so.
# 2                                           Let's go.
# 3      Okay -- you're gonna need to learn how to lie.
# 4                    Like my fear of wearing pastels?
# 5                                    What good stuff?
# 6   Me.  This endless ...blonde babble. I'm like b...
# 7                         do you listen to this crap?
# 8                                                 But
# 9                                          Well no...
# 10                                             I was?
# 11                                               Tons
# 12                                 You know Chastity?
# 13                                                Hi.
# 14  Who knows?  All I've ever heard her say is tha...
# 15  Lesbian?  No. I found a picture of Jared Leto ...
# 16  I really really really wanna go but I can't.  ...
# 17  Eber's Deep Conditioner every two days. And I ...
# 18                                      You're sweet.
# 19  I counted on you to help my cause. You and tha...

# %%
final_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 288716 entries, 0 to 288715
# Data columns (total 13 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   movie_id          288716 non-null  object
#  1   movie_name        288715 non-null  object
#  2   movie_year        288715 non-null  object
#  3   movie_rating      288715 non-null  float64
#  4   movie_genre       288715 non-null  object
#  5   director_name     288716 non-null  object
#  6   director_gender   288716 non-null  object
#  7   character_id      288715 non-null  object
#  8   character_name    288672 non-null  object
#  9   character_gender  288715 non-null  object
#  10  position_credits  288715 non-null  object
#  11  line_id           288447 non-null  object
#  12  character_line    288193 non-null  object
# dtypes: float64(1), object(12)
# memory usage: 30.8+ MB

# %%
print("Distribution Of NaN across dataframe")
nan_percentage = (final_df.isna().mean() * 100).round(5)
print(nan_percentage)
# Out:
# Distribution Of NaN across dataframe
# movie_id            0.00000
# movie_name          0.00035
# movie_year          0.00035
# movie_rating        0.00035
# movie_genre         0.00035
# director_name       0.00000
# director_gender     0.00000
# character_id        0.00035
# character_name      0.01524
# character_gender    0.00035
# position_credits    0.00035
# line_id             0.09317
# character_line      0.18115
# dtype: float64

# %%
num_rows_dropped = final_df.isna().any(axis=1).sum()
print("Number of rows that would be dropped due to NaN:", num_rows_dropped)
# Out:
# Number of rows that would be dropped due to NaN: 566

# %%
# Removing rows with NaN values
final_df = final_df.dropna()

# %%
# Remove duplicate rows
duplicate_counts = final_df.duplicated().sum()
print("Total duplicate", duplicate_counts)
if duplicate_counts > 0:
  characters_df = final_df.drop_duplicates()
# Out:
# Total duplicate 0

# %%
column_name = 'movie_year'

# Filter non-numeric values in the specified column
non_numeric_values = final_df.loc[~pd.to_numeric(final_df[column_name], errors='coerce').notna(), column_name]

# Get unique non-numeric values
unique_non_numeric_values = non_numeric_values.unique()

# Display the unique non-numeric values
print("Unique non-numeric values in column '{}':".format(column_name))
print(unique_non_numeric_values)
# Out:
# Unique non-numeric values in column 'movie_year':
# ['1989/I' '1990/I' '1995/I' '1998/I' '2004/I' '2007/I' '1992/I' '2005/I'
#  '2002/I' '1968/I' '1996/I' '2000/I' '2009/I' '2003/I']

# %%
column_name = 'movie_year'

# Extract numeric portion using regular expression
final_df[column_name] = final_df[column_name].str.extract('(\d+)', expand=False)
final_df[column_name] = final_df[column_name].astype(int)

# %%
final_df.movie_year.unique()
# Out:
# array([1999, 1992, 2001, 1968, 1982, 1997, 1988, 1989, 1959, 1980, 1986,
#        1984, 1981, 1932, 2000, 1998, 1991, 1975, 2003, 2006, 1996, 2004,
#        1995, 1942, 1974, 1990, 1933, 1993, 2005, 1931, 2009, 2002, 1967,
#        1971, 1979, 1987, 1940, 1961, 2007, 1953, 1934, 1983, 1994, 1985,
#        1976, 1937, 1955, 1970, 1941, 1927, 1939, 1936, 1954, 1949, 1943,
#        2010, 1977, 1972, 1963, 1945, 2008, 1960, 1964, 1950, 1973, 1966,
#        1944, 1978, 1946, 1969, 1965, 1957, 1958])

# %%
##Count of values of each gender type
final_df.character_gender.value_counts()
# Out:
# m    145845
# f     63284
# ?     59044
# M     15399
# F      4578
# Name: character_gender, dtype: int64

# %%
##Data Analysis to check if any chId has multiple gender assigned to it.
##Result: None found
grouped = final_df.groupby('character_id')['character_gender'].nunique()
characters_with_multiple_genders = grouped[grouped > 1].index.tolist()
print("characters with more than one gender:", len(characters_with_multiple_genders))
# Out:
# characters with more than one gender: 0

# %%
##Removing data ambiguity from gender
final_df = final_df[final_df.character_gender != '?']
final_df.character_gender = final_df.character_gender.apply(lambda g: 'M' if g in ['m', 'M'] else 'F')
print("Data Distribution Per Gender:")
final_df.groupby('character_gender')['character_id'].nunique()
# Out:
# Data Distribution Per Gender:
# character_gender
# F     948
# M    2003
# Name: character_id, dtype: int64

# %%
final_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 229106 entries, 0 to 288617
# Data columns (total 13 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   movie_id          229106 non-null  object
#  1   movie_name        229106 non-null  object
#  2   movie_year        229106 non-null  int64
#  3   movie_rating      229106 non-null  float64
#  4   movie_genre       229106 non-null  object
#  5   director_name     229106 non-null  object
#  6   director_gender   229106 non-null  object
#  7   character_id      229106 non-null  object
#  8   character_name    229106 non-null  object
#  9   character_gender  229106 non-null  object
#  10  position_credits  229106 non-null  object
#  11  line_id           229106 non-null  object
#  12  character_line    229106 non-null  object
# dtypes: float64(1), int64(1), object(11)
# memory usage: 24.5+ MB

# %%
non_numeric_position_credits = final_df.loc[~pd.to_numeric(final_df['position_credits'], errors='coerce').notna(), 'position_credits'].unique()
print("Non-numeric values in 'position_credits' column:", non_numeric_position_credits)


#Examine the distribution of male & female with this junk data
filtered_df = final_df[final_df['position_credits'] == '?']
# Count the number of males and females
male_count = filtered_df[filtered_df['character_gender'] == 'M']
female_count = filtered_df[filtered_df['character_gender'] == 'F']

print("Number of males with position_credits = '?':", male_count.groupby('character_gender')['character_id'].nunique())
print("Number of females with position_credits = '?':", female_count.groupby('character_gender')['character_id'].nunique())
# Out:
# Non-numeric values in 'position_credits' column: ['?']
# Number of males with position_credits = '?': character_gender
# M    222
# Name: character_id, dtype: int64
# Number of females with position_credits = '?': character_gender
# F    102
# Name: character_id, dtype: int64

# %%
final_df['position_credits'] = final_df['position_credits'].replace('?', -1).astype(int)
final_df.describe()
# Out:
#           movie_year   movie_rating  position_credits
# count  229106.000000  229106.000000     229106.000000
# mean     1987.891264       6.992279          9.579243
# std        17.314424       1.146805         79.434358
# min      1927.000000       2.500000         -1.000000
# 25%      1984.000000       6.400000          1.000000
# 50%      1995.000000       7.200000          2.000000
# 75%      1999.000000       7.800000          4.000000
# max      2010.000000       9.300000       1000.000000

# %%
##Get the number of unique dialogues spoken by each characters.
final_df['character_dialog_count'] = final_df.groupby(['character_id', 'movie_id'])['character_line'].transform('count')

##Get the number of words per dialogue
final_df['dialog_word_count'] = final_df.character_line.str.count(' ') + 1

# %%
final_df.head()
# Out:
#   movie_id                  movie_name  movie_year  movie_rating  \
# 0       m0  10 things i hate about you        1999           6.9
# 1       m0  10 things i hate about you        1999           6.9
# 2       m0  10 things i hate about you        1999           6.9
# 3       m0  10 things i hate about you        1999           6.9
# 4       m0  10 things i hate about you        1999           6.9
#
#             movie_genre director_name director_gender character_id  \
# 0  ['comedy' 'romance']    Gil Junger               M           u0
# 1  ['comedy' 'romance']    Gil Junger               M           u0
# 2  ['comedy' 'romance']    Gil Junger               M           u0
# 3  ['comedy' 'romance']    Gil Junger               M           u0
# 4  ['comedy' 'romance']    Gil Junger               M           u0
#
#   character_name character_gender  position_credits line_id  \
# 0         BIANCA                F                 4   L1045
# 1         BIANCA                F                 4    L985
# 2         BIANCA                F                 4    L925
# 3         BIANCA                F                 4    L872
# 4         BIANCA                F                 4    L869
#
#                                    character_line  character_dialog_count  \
# 0                                    They do not!                      94
# 1                                      I hope so.                      94
# 2                                       Let's go.                      94
# 3  Okay -- you're gonna need to learn how to lie.                      94
# 4                Like my fear of wearing pastels?                      94
#
#    dialog_word_count
# 0                  3
# 1                  3
# 2                  2
# 3                 10
# 4                  6

# %%
df=final_df

# %% [markdown]
# ###Creating Wordcloud out of Movie Names

# %%
movie_names_df = df.drop_duplicates(subset = "movie_id")
movie_names_df.movie_name
# Out:
# 0         10 things i hate about you
# 694       1492: conquest of paradise
# 927                       15 minutes
# 1605           2001: a space odyssey
# 1906                         48 hrs.
#                      ...
# 286252              the wizard of oz
# 286830       the world is not enough
# 287162                      watchmen
# 287505                           xxx
# 288098            young frankenstein
# Name: movie_name, Length: 588, dtype: object

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt
#Concatenate all dialogue lines
all_lines = ' '.join(movie_names_df['movie_name'])

#Create a word cloud with larger figure size
plt.figure(figsize=(15, 10))
wordcloud = WordCloud(width=800, height=400, background_color='black').generate(all_lines)
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.title('Word Cloud of Movie Titles')
plt.show()

# %% [markdown]
# The most frequent words in the movie titles are **“star”, “trek”, “black”, “men”, “day”, “night”, “american”, “dead”, “thing”, “house”, “nightmare”, “elm”, “street”, “batman”, “jurassic”, “park”, “wild”, “lost”, “world”, “brown”, “jaws”, “mission”, “impossible”, “voyage”, “earth”, “game”, “happy”, “hotel”, “meet”, “hard”, “scream”, “basic”, “rush”, “13th”, “part”, “final”, “blue”, “hellraiser”, “dark”, “friday”, “thing”, “scream” **.
#
# <br>
#
#
#
# Based on this word cloud, we can conclude that the most common themes in the movie titles are related to **science fiction, horror, action, and adventure genres**. The words “star”, “trek”, “black”, “men”, “day”, “night”, “american”, “dead”, “thing”, “house”, “nightmare”, “elm”, “street”, “batman”, “jurassic”, “park”, “wild”, “lost”, “world”, “brown”, “jaws”, “mission”, “impossible”, “voyage”, “earth”, “game”, “happy”, “hotel”, “meet”, “hard”, “scream”, “basic”, “rush”, “13th”, “part”, “final”, “blue”, “hellraiser”, “dark”, “friday”, “thing”, and “scream” are indicative of the most popular movie franchises and titles in these genres.

# %% [markdown]
# ### Creating Wordcloud out of Character Names

# %%
character_names_df = df.drop_duplicates(subset = "character_id")
character_names_df.character_name
# Out:
# 0                  BIANCA
# 97                CAMERON
# 180                  JOEY
# 216                   KAT
# 367              MANDELLA
#                ...
# 288098          ELIZABETH
# 288153             FREDDY
# 288422               IGOR
# 288524               INGA
# 288604    MEDICAL STUDENT
# Name: character_name, Length: 2951, dtype: object

# %%
from wordcloud import WordCloud

#Concatenate all dialogue lines
all_lines = ' '.join(character_names_df['character_name'])

#Create a word cloud with larger figure size
plt.figure(figsize=(15, 10))
wordcloud = WordCloud(width=800, height=400, background_color='white').generate(all_lines)
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.title('Word Cloud based on Character Names')
plt.show()

# %% [markdown]
# Based on the word cloud, we can conclude that the most common character names in the 588 movies are ***Jack, John, Michael, George, and Nick***. We can also see that there are other names that are less common, but still appear in the word cloud such as ***Paul, Sam, Betty, Kirk, and Tom***.

# %% [markdown]
# ### Gender Distribution of movie Characters across movies in given data

# %%
Gender_distribution = df.drop_duplicates(subset = "character_id")
Gender_distribution
# Out:
#        movie_id                  movie_name  movie_year  movie_rating  \
# 0            m0  10 things i hate about you        1999           6.9
# 97           m0  10 things i hate about you        1999           6.9
# 180          m0  10 things i hate about you        1999           6.9
# 216          m0  10 things i hate about you        1999           6.9
# 367          m0  10 things i hate about you        1999           6.9
# ...         ...                         ...         ...           ...
# 288098     m615          young frankenstein        1974           8.0
# 288153     m615          young frankenstein        1974           8.0
# 288422     m615          young frankenstein        1974           8.0
# 288524     m615          young frankenstein        1974           8.0
# 288604     m615          young frankenstein        1974           8.0
#
#                  movie_genre director_name director_gender character_id  \
# 0       ['comedy' 'romance']    Gil Junger               M           u0
# 97      ['comedy' 'romance']    Gil Junger               M           u2
# 180     ['comedy' 'romance']    Gil Junger               M           u4
# 216     ['comedy' 'romance']    Gil Junger               M           u5
# 367     ['comedy' 'romance']    Gil Junger               M           u6
# ...                      ...           ...             ...          ...
# 288098   ['comedy' 'sci-fi']    Mel Brooks               M        u9015
# 288153   ['comedy' 'sci-fi']    Mel Brooks               M        u9017
# 288422   ['comedy' 'sci-fi']    Mel Brooks               M        u9019
# 288524   ['comedy' 'sci-fi']    Mel Brooks               M        u9020
# 288604   ['comedy' 'sci-fi']    Mel Brooks               M        u9022
#
#          character_name character_gender  position_credits  line_id  \
# 0                BIANCA                F                 4    L1045
# 97              CAMERON                M                 3    L1044
# 180                JOEY                M                 6     L759
# 216                 KAT                F                 2    L1052
# 367            MANDELLA                F                 7     L948
# ...                 ...              ...               ...      ...
# 288098        ELIZABETH                F                25  L666202
# 288153           FREDDY                M                -1  L666092
# 288422             IGOR                M                 3  L665975
# 288524             INGA                F                 5  L666221
# 288604  MEDICAL STUDENT                M                 9  L665449
#
#                                            character_line  \
# 0                                            They do not!
# 97                                            They do to!
# 180          Listen I want to talk to you about the prom.
# 216                                                 Perm?
# 367               William - he asked me to meet him here.
# ...                                                   ...
# 288098  So this is what it's like to be completely happy!
# 288153  I think we all need a good night's sleep.  Why...
# 288422                                           Miss me?
# 288524               Sweetheart.....Is this really you???
# 288604                 But your grandfather's work sir...
#
#         character_dialog_count  dialog_word_count
# 0                           94                  3
# 97                          75                  3
# 180                         36                 10
# 216                        150                  1
# 367                         25                  9
# ...                        ...                ...
# 288098                      44                 10
# 288153                     252                 21
# 288422                     102                  2
# 288524                      73                  4
# 288604                      14                  5
#
# [2951 rows x 15 columns]

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Count the occurrences of each unique value in 'character_gender'
gender_counts = Gender_distribution['character_gender'].value_counts()

# Create a horizontal bar plot using seaborn with custom colors
sns.set(style="whitegrid")
plt.figure(figsize=(8, 5))  # Adjust the figure size as needed
ax = sns.barplot(x=gender_counts.values, y=gender_counts.index, palette=['#cedcab', '#e27557'], edgecolor='black')

# Set labels and title
plt.xlabel('Count')
plt.ylabel('Gender')
plt.title('Distribution of Character Gender')

# Remove grid lines
ax.grid(False)

# Add count labels on the bars
for i, v in enumerate(gender_counts.values):
    ax.text(v + 0.1, i, str(v), color='black', ha='left', va='center')

# Show the plot
plt.show()

# %% [markdown]
# We have total of **2951 Characters** across 588 Movies.
#
# Out of these ***2003 Characters are of Male Gender and 948 Female***

# %% [markdown]
# ### Now, Let's see how the data for movies is distributed over the years italicized text

# %%
movie_year_df = df.drop_duplicates(subset = "movie_id")
movie_year_df
# Out:
#        movie_id                  movie_name  movie_year  movie_rating  \
# 0            m0  10 things i hate about you        1999           6.9
# 694          m1  1492: conquest of paradise        1992           6.2
# 927          m2                  15 minutes        2001           6.1
# 1605         m3       2001: a space odyssey        1968           8.4
# 1906         m4                     48 hrs.        1982           6.9
# ...         ...                         ...         ...           ...
# 286252     m610            the wizard of oz        1939           8.3
# 286830     m611     the world is not enough        1999           6.3
# 287162     m612                    watchmen        2009           7.8
# 287505     m613                         xxx        2002           5.6
# 288098     m615          young frankenstein        1974           8.0
#
#                                               movie_genre    director_name  \
# 0                                    ['comedy' 'romance']       Gil Junger
# 694           ['adventure' 'biography' 'drama' 'history']     Ridley Scott
# 927                 ['action' 'crime' 'drama' 'thriller']    John Herzfeld
# 1605                     ['adventure' 'mystery' 'sci-fi']  Stanley Kubrick
# 1906       ['action' 'comedy' 'crime' 'drama' 'thriller']      Walter Hill
# ...                                                   ...              ...
# 286252         ['adventure' 'family' 'fantasy' 'musical']          Unknown
# 286830                  ['action' 'adventure' 'thriller']    Michael Apted
# 287162  ['action' 'crime' 'fantasy' 'mystery' 'sci-fi'...      Zack Snyder
# 287505                     ['action' 'adventure' 'crime']        Rob Cohen
# 288098                                ['comedy' 'sci-fi']       Mel Brooks
#
#        director_gender character_id character_name character_gender  \
# 0                    M           u0         BIANCA                F
# 694                  M          u16       COLUMBUS                M
# 927                  M          u26         CUTLER                M
# 1605                 M          u50         BOWMAN                M
# 1906                 M          u67          CATES                M
# ...                ...          ...            ...              ...
# 286252         Unknown        u8950        DOROTHY                F
# 286830               M        u8965           BOND                M
# 287162               M        u8979  DR. MANHATTAN                M
# 287505               M        u8991        GIBBONS                M
# 288098               M        u9015      ELIZABETH                F
#
#         position_credits  line_id  \
# 0                      4    L1045
# 694                    1    L2024
# 927                   -1    L3546
# 1605                   1    L4300
# 1906                   1    L5328
# ...                  ...      ...
# 286252                 1  L660491
# 286830                 1  L663195
# 287162                 2  L664175
# 287505                 4  L665330
# 288098                25  L666202
#
#                                            character_line  \
# 0                                            They do not!
# 694     Asia can be found to the west -- and I will pr...
# 927     Officers there's your killer do your duty arre...
# 1605                                               Roger.
# 1906                                        Where's ganz?
# ...                                                   ...
# 286252  No Aunt Em -- this was a real truly live place...
# 286830                        I love Christmas in Turkey.
# 287162                          WHAT ARE YOU DOING VEIDT?
# 287505  All for show. Just a psychological mind game t...
# 288098  So this is what it's like to be completely happy!
#
#         character_dialog_count  dialog_word_count
# 0                           94                  3
# 694                        117                 13
# 927                         24                  9
# 1605                        58                  1
# 1906                       224                  2
# ...                        ...                ...
# 286252                     187                 22
# 286830                     131                  5
# 287162                      35                  5
# 287505                      51                 16
# 288098                      44                 10
#
# [588 rows x 15 columns]

# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.cm import ScalarMappable

# Count the occurrences of each year based on unique mId values
year_counts_unique = movie_year_df.groupby('movie_year')['movie_id'].nunique()

# Create a color gradient
colors = plt.cm.viridis(np.linspace(0, 1, len(year_counts_unique)))

# Create a bar plot for year distribution based on unique mId
plt.figure(figsize=(18, 8))  # Adjust the figure size as needed
bars = plt.bar(year_counts_unique.index.astype(str), year_counts_unique, color=colors)
plt.xlabel('Year')
plt.ylabel('Count (Unique mId)')
plt.title('Distribution of Unique Movies Over the Years')

# Remove grids
plt.grid(False)

# Create a ScalarMappable to create a colorbar
sm = ScalarMappable(cmap=plt.cm.viridis)
sm.set_array([])  # An array must be set, but it can be empty

# Add a color bar for the gradient
color_bar = plt.colorbar(sm, orientation='vertical', pad=0.05)
color_bar.set_label('Color Gradient')

# Adjust x-axis limits for a little space on both sides
plt.margins(x=0.05)

plt.xticks(rotation=90)  # Rotate x-axis labels for better readability

# Show the plot
plt.show()

# %% [markdown]
# The data ranges from the year 1926 all the way upto 2010. While we have wide-ranging data, the majority of it lies in the 3 decades of the 1980s, 1990s and 2000s, with 490 of the 617 i.e., ∼79% of the movies in that period. This sample space has enough of a time-spread for us to analyze how representation of women and the general attitude towards them in movies has changed over time.

# %% [markdown]
# ### Analysing Movies for Ratings Received

# %%
movie_rating_df = df.drop_duplicates(subset = "movie_id")
movie_rating_df
# Out:
#        movie_id                  movie_name  movie_year  movie_rating  \
# 0            m0  10 things i hate about you        1999           6.9
# 694          m1  1492: conquest of paradise        1992           6.2
# 927          m2                  15 minutes        2001           6.1
# 1605         m3       2001: a space odyssey        1968           8.4
# 1906         m4                     48 hrs.        1982           6.9
# ...         ...                         ...         ...           ...
# 286252     m610            the wizard of oz        1939           8.3
# 286830     m611     the world is not enough        1999           6.3
# 287162     m612                    watchmen        2009           7.8
# 287505     m613                         xxx        2002           5.6
# 288098     m615          young frankenstein        1974           8.0
#
#                                               movie_genre    director_name  \
# 0                                    ['comedy' 'romance']       Gil Junger
# 694           ['adventure' 'biography' 'drama' 'history']     Ridley Scott
# 927                 ['action' 'crime' 'drama' 'thriller']    John Herzfeld
# 1605                     ['adventure' 'mystery' 'sci-fi']  Stanley Kubrick
# 1906       ['action' 'comedy' 'crime' 'drama' 'thriller']      Walter Hill
# ...                                                   ...              ...
# 286252         ['adventure' 'family' 'fantasy' 'musical']          Unknown
# 286830                  ['action' 'adventure' 'thriller']    Michael Apted
# 287162  ['action' 'crime' 'fantasy' 'mystery' 'sci-fi'...      Zack Snyder
# 287505                     ['action' 'adventure' 'crime']        Rob Cohen
# 288098                                ['comedy' 'sci-fi']       Mel Brooks
#
#        director_gender character_id character_name character_gender  \
# 0                    M           u0         BIANCA                F
# 694                  M          u16       COLUMBUS                M
# 927                  M          u26         CUTLER                M
# 1605                 M          u50         BOWMAN                M
# 1906                 M          u67          CATES                M
# ...                ...          ...            ...              ...
# 286252         Unknown        u8950        DOROTHY                F
# 286830               M        u8965           BOND                M
# 287162               M        u8979  DR. MANHATTAN                M
# 287505               M        u8991        GIBBONS                M
# 288098               M        u9015      ELIZABETH                F
#
#         position_credits  line_id  \
# 0                      4    L1045
# 694                    1    L2024
# 927                   -1    L3546
# 1605                   1    L4300
# 1906                   1    L5328
# ...                  ...      ...
# 286252                 1  L660491
# 286830                 1  L663195
# 287162                 2  L664175
# 287505                 4  L665330
# 288098                25  L666202
#
#                                            character_line  \
# 0                                            They do not!
# 694     Asia can be found to the west -- and I will pr...
# 927     Officers there's your killer do your duty arre...
# 1605                                               Roger.
# 1906                                        Where's ganz?
# ...                                                   ...
# 286252  No Aunt Em -- this was a real truly live place...
# 286830                        I love Christmas in Turkey.
# 287162                          WHAT ARE YOU DOING VEIDT?
# 287505  All for show. Just a psychological mind game t...
# 288098  So this is what it's like to be completely happy!
#
#         character_dialog_count  dialog_word_count
# 0                           94                  3
# 694                        117                 13
# 927                         24                  9
# 1605                        58                  1
# 1906                       224                  2
# ...                        ...                ...
# 286252                     187                 22
# 286830                     131                  5
# 287162                      35                  5
# 287505                      51                 16
# 288098                      44                 10
#
# [588 rows x 15 columns]

# %%
movie_rating_df.movie_rating.describe()
# Out:
# count    588.000000
# mean       6.867347
# std        1.216800
# min        2.500000
# 25%        6.200000
# 50%        7.100000
# 75%        7.800000
# max        9.300000
# Name: movie_rating, dtype: float64

# %% [markdown]
# We observe that the highest Rated movie had 9.3 Rating

# %%
import matplotlib.pyplot as plt
import seaborn as sns

#Assuming your analysis DataFrame is named analysis_df
#Extract the 'movie_rating' column for plotting
movie_ratings = movie_rating_df['movie_rating']

#Create a histogram for movie ratings
plt.figure(figsize=(10, 6))
sns.histplot(movie_ratings, bins=20, kde=True, color='#6aaa96')
plt.xlabel('Movie Rating')
plt.ylabel('Count')
plt.title('Distribution of Movie Ratings')

# Remove grids
plt.grid(False)

#Show the plot
plt.show()

# %% [markdown]
# Based on the graph, we can conclude that the majority of the movies have a rating between 6 and 8. The highest number of ratings is around 7.5. This suggests that most movies are rated between 6 and 8, with a few outliers on either end.
#
# **9.5 is the highest rating received by any movie in our current dataset.**

# %% [markdown]
# ### Let's Explore dialogue count per Gender

# %%
gender_dialogue_df = df.drop_duplicates(subset = "character_id")
gender_dialogue_df
# Out:
#        movie_id                  movie_name  movie_year  movie_rating  \
# 0            m0  10 things i hate about you        1999           6.9
# 97           m0  10 things i hate about you        1999           6.9
# 180          m0  10 things i hate about you        1999           6.9
# 216          m0  10 things i hate about you        1999           6.9
# 367          m0  10 things i hate about you        1999           6.9
# ...         ...                         ...         ...           ...
# 288098     m615          young frankenstein        1974           8.0
# 288153     m615          young frankenstein        1974           8.0
# 288422     m615          young frankenstein        1974           8.0
# 288524     m615          young frankenstein        1974           8.0
# 288604     m615          young frankenstein        1974           8.0
#
#                  movie_genre director_name director_gender character_id  \
# 0       ['comedy' 'romance']    Gil Junger               M           u0
# 97      ['comedy' 'romance']    Gil Junger               M           u2
# 180     ['comedy' 'romance']    Gil Junger               M           u4
# 216     ['comedy' 'romance']    Gil Junger               M           u5
# 367     ['comedy' 'romance']    Gil Junger               M           u6
# ...                      ...           ...             ...          ...
# 288098   ['comedy' 'sci-fi']    Mel Brooks               M        u9015
# 288153   ['comedy' 'sci-fi']    Mel Brooks               M        u9017
# 288422   ['comedy' 'sci-fi']    Mel Brooks               M        u9019
# 288524   ['comedy' 'sci-fi']    Mel Brooks               M        u9020
# 288604   ['comedy' 'sci-fi']    Mel Brooks               M        u9022
#
#          character_name character_gender  position_credits  line_id  \
# 0                BIANCA                F                 4    L1045
# 97              CAMERON                M                 3    L1044
# 180                JOEY                M                 6     L759
# 216                 KAT                F                 2    L1052
# 367            MANDELLA                F                 7     L948
# ...                 ...              ...               ...      ...
# 288098        ELIZABETH                F                25  L666202
# 288153           FREDDY                M                -1  L666092
# 288422             IGOR                M                 3  L665975
# 288524             INGA                F                 5  L666221
# 288604  MEDICAL STUDENT                M                 9  L665449
#
#                                            character_line  \
# 0                                            They do not!
# 97                                            They do to!
# 180          Listen I want to talk to you about the prom.
# 216                                                 Perm?
# 367               William - he asked me to meet him here.
# ...                                                   ...
# 288098  So this is what it's like to be completely happy!
# 288153  I think we all need a good night's sleep.  Why...
# 288422                                           Miss me?
# 288524               Sweetheart.....Is this really you???
# 288604                 But your grandfather's work sir...
#
#         character_dialog_count  dialog_word_count
# 0                           94                  3
# 97                          75                  3
# 180                         36                 10
# 216                        150                  1
# 367                         25                  9
# ...                        ...                ...
# 288098                      44                 10
# 288153                     252                 21
# 288422                     102                  2
# 288524                      73                  4
# 288604                      14                  5
#
# [2951 rows x 15 columns]

# %%
dialogue_per_gender = gender_dialogue_df.groupby('character_gender')['character_dialog_count'].sum()

# %%
dialogue_per_gender
# Out:
# character_gender
# F     67862
# M    161244
# Name: character_dialog_count, dtype: int64

# %%
import pandas as pd
import matplotlib.pyplot as plt
dialogue_df = pd.DataFrame({'Gender':['Female', 'Male'], 'dialogue_per_gender':[dialogue_per_gender[0], dialogue_per_gender[1]]})

# Create a bar plot
ax = dialogue_df.plot.bar(x='Gender', y='dialogue_per_gender', rot=0, color=['skyblue', 'lightcoral'])
ax.get_legend().remove()
# Add labels and title
plt.xlabel('Gender')
plt.ylabel('Number of Dialogues')
plt.title('Dialogues Count by Gender')
plt.grid(False)
# Show the plot
plt.show()

# %% [markdown]
# The bar graph illustrates the distribution of dialogues between female and male characters.The data indicates that male characters have significantly more dialogues **(161244)** compared to female characters **(67862)**. This suggests a potential gender imbalance in the dataset or narrative focus.
#
# The substantial difference in dialogue counts raises questions about the representation of female characters in the context of the dataset. The analysis may prompt further investigation into the storyline, genre, or specific characters contributing to these numbers.

# %%
import pandas as pd
import numpy as np
import re
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from wordcloud import WordCloud
import matplotlib.pyplot as plt
import seaborn as sns
import warnings

from sklearn.preprocessing import OneHotEncoder, StandardScaler, MinMaxScaler
from sklearn.compose import ColumnTransformer
from sklearn.feature_extraction.text import TfidfTransformer, CountVectorizer, TfidfVectorizer
from sklearn.preprocessing import FunctionTransformer
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import MultinomialNB
from sklearn.ensemble import RandomForestClassifier,BaggingClassifier
from sklearn.svm import SVC
from sklearn.calibration import CalibratedClassifierCV
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.pipeline import FeatureUnion, Pipeline
from sklearn.model_selection import train_test_split
from sklearn.base import BaseEstimator, TransformerMixin
from sklearn import svm
from sklearn.multiclass import OneVsRestClassifier
from sklearn.svm import LinearSVC

from imblearn.under_sampling import RandomUnderSampler

import IPython
from IPython.display import display
import graphviz
from sklearn.tree import export_graphviz
import re


warnings.filterwarnings('ignore')
pd.set_option('display.max_rows', 100)

# %%
lines_df = pd.read_csv('movie_lines.tsv', sep='\t', error_bad_lines=False,
                       warn_bad_lines=False, header=None)
characters_df = pd.read_csv('movie_characters_metadata.tsv', sep='\t', warn_bad_lines=False,
                            error_bad_lines=False, header=None)

characters_df.head()
# Out:
#     0         1   2                           3  4  5
# 0  u0    BIANCA  m0  10 things i hate about you  f  4
# 1  u1     BRUCE  m0  10 things i hate about you  ?  ?
# 2  u2   CAMERON  m0  10 things i hate about you  m  3
# 3  u3  CHASTITY  m0  10 things i hate about you  ?  ?
# 4  u4      JOEY  m0  10 things i hate about you  m  6

# %% [markdown]
# Adding column names to characters dataframe

# %%
characters_df.columns=['chId','chName','mId','mName','gender','posCredits']
characters_df.head()
# Out:
#   chId    chName mId                       mName gender posCredits
# 0   u0    BIANCA  m0  10 things i hate about you      f          4
# 1   u1     BRUCE  m0  10 things i hate about you      ?          ?
# 2   u2   CAMERON  m0  10 things i hate about you      m          3
# 3   u3  CHASTITY  m0  10 things i hate about you      ?          ?
# 4   u4      JOEY  m0  10 things i hate about you      m          6

# %%
characters_df.shape
# Out:
# (9034, 6)

# %% [markdown]
# Checking the distribution of gender in the characters dataset

# %%
characters_df.gender.value_counts()
# Out:
# ?    6008
# m    1899
# f     921
# M     145
# F      44
# Name: gender, dtype: int64

# %% [markdown]
# We need to clean this column. Let's also remove the characters were gender information is not available. We'll assign a label of 0 to male characters & 1 to female characters.

# %%
characters_df = characters_df[characters_df.gender != '?']
characters_df.gender = characters_df.gender.apply(lambda g: 0 if g in ['m', 'M'] else 1)  ## Label encoding

characters_df.shape
# Out:
# (3026, 6)

# %%
characters_df.gender.value_counts()
# Out:
# 0    2044
# 1     982
# Name: gender, dtype: int64

# %% [markdown]
# Let's also take a look at the position of the character in the post credits of the movie

# %%
characters_df.posCredits.value_counts()
# Out:
# 1       497
# 2       443
# 3       352
# ?       330
# 4       268
# 5       211
# 6       169
# 7       125
# 8       100
# 9        79
# 10       54
# 11       40
# 1000     38
# 13       33
# 12       32
# 16       26
# 14       24
# 18       24
# 17       19
# 19       18
# 15       14
# 21       13
# 22        9
# 20        8
# 29        7
# 27        6
# 26        5
# 25        5
# 24        5
# 31        4
# 35        4
# 23        4
# 45        4
# 43        3
# 34        3
# 33        3
# 38        3
# 42        2
# 36        2
# 32        2
# 30        2
# 39        2
# 59        2
# 28        2
# 49        1
# 63        1
# 44        1
# 37        1
# 50        1
# 82        1
# 51        1
# 46        1
# 62        1
# 47        1
# 41        1
# 71        1
# 70        1
# Name: posCredits, dtype: int64

# %% [markdown]
# The position of characters in the credits section seems to be a useful feature for classification. We can try to use it as a categorical variable later. But let's combine the low frequency ones together first.

# %%
characters_df.posCredits = characters_df.posCredits.apply(lambda p: '10+' if not p in ['1', '2', '3', '4', '5', '6', '7', '8', '9'] else p)  ## Label encoding
characters_df.posCredits.value_counts()
# Out:
# 10+    782
# 1      497
# 2      443
# 3      352
# 4      268
# 5      211
# 6      169
# 7      125
# 8      100
# 9       79
# Name: posCredits, dtype: int64

# %% [markdown]
# Let's clean the lines dataframe now!

# %%
lines_df.columns = ['lineId','chId','mId','chName','dialogue']
lines_df.head()
# Out:
#   lineId chId mId   chName      dialogue
# 0  L1045   u0  m0   BIANCA  They do not!
# 1  L1044   u2  m0  CAMERON   They do to!
# 2   L985   u0  m0   BIANCA    I hope so.
# 3   L984   u2  m0  CAMERON     She okay?
# 4   L925   u0  m0   BIANCA     Let's go.

# %% [markdown]
# Let's join lines_df and characters_df together.

# %%
df = pd.merge(lines_df, characters_df, how='inner', on=['chId','mId', 'chName'],
         left_index=False, right_index=False, sort=True,
         copy=False, indicator=False)
df.head()
# Out:
#   lineId chId mId  chName                                        dialogue  \
# 0  L1045   u0  m0  BIANCA                                    They do not!
# 1   L985   u0  m0  BIANCA                                      I hope so.
# 2   L925   u0  m0  BIANCA                                       Let's go.
# 3   L872   u0  m0  BIANCA  Okay -- you're gonna need to learn how to lie.
# 4   L869   u0  m0  BIANCA                Like my fear of wearing pastels?
#
#                         mName  gender posCredits
# 0  10 things i hate about you       1          4
# 1  10 things i hate about you       1          4
# 2  10 things i hate about you       1          4
# 3  10 things i hate about you       1          4
# 4  10 things i hate about you       1          4

# %%
df.shape
# Out:
# (229309, 8)

# %% [markdown]
# Remove empty dialogues from the dataset

# %%
df = df[df['dialogue'].notnull()]
df.shape
# Out:
# (229106, 8)

# %% [markdown]
# Adding movie metadata like year of release to the dataset

# %%
movies = pd.read_csv("movie_titles_metadata.tsv", sep='\t', error_bad_lines=False,
                       warn_bad_lines=False, header=None)
movies.columns = ['mId','mName','releaseYear','rating','votes','genres']

movies.head()
# Out:
#   mId                       mName releaseYear  rating     votes  \
# 0  m0  10 things i hate about you        1999     6.9   62847.0
# 1  m1  1492: conquest of paradise        1992     6.2   10421.0
# 2  m2                  15 minutes        2001     6.1   25854.0
# 3  m3       2001: a space odyssey        1968     8.4  163227.0
# 4  m4                     48 hrs.        1982     6.9   22289.0
#
#                                            genres
# 0                            ['comedy' 'romance']
# 1     ['adventure' 'biography' 'drama' 'history']
# 2           ['action' 'crime' 'drama' 'thriller']
# 3                ['adventure' 'mystery' 'sci-fi']
# 4  ['action' 'comedy' 'crime' 'drama' 'thriller']

# %%
movie_yr = movies[['mId', 'releaseYear']]
movie_yr.releaseYear = pd.to_numeric(movie_yr.releaseYear.apply(lambda y: str(y)[0:4]), errors='coerce')
movie_yr = movie_yr.dropna()
movie_yr.releaseYear.value_counts()
# Out:
# 1999.0    42
# 2000.0    41
# 1997.0    38
# 1998.0    37
# 2001.0    30
# 1996.0    24
# 1995.0    22
# 1994.0    19
# 1992.0    19
# 1989.0    19
# 2002.0    18
# 1993.0    18
# 2003.0    16
# 1987.0    15
# 1991.0    14
# 2004.0    14
# 1982.0    14
# 1988.0    13
# 1990.0    11
# 1984.0    11
# 1986.0    11
# 1985.0    11
# 2005.0     9
# 1975.0     9
# 1979.0     8
# 1971.0     7
# 2006.0     6
# 1980.0     6
# 2007.0     5
# 1983.0     5
# 1974.0     5
# 1978.0     5
# 1973.0     4
# 1932.0     4
# 1977.0     4
# 1976.0     4
# 1972.0     3
# 1955.0     3
# 1968.0     3
# 1960.0     3
# 1954.0     3
# 1939.0     3
# 1981.0     3
# 1934.0     3
# 1953.0     3
# 1964.0     3
# 2009.0     3
# 1943.0     3
# 1959.0     3
# 1949.0     3
# 1950.0     2
# 1945.0     2
# 1963.0     2
# 1966.0     2
# 1961.0     2
# 1931.0     2
# 1927.0     2
# 1941.0     2
# 1970.0     2
# 1940.0     2
# 1967.0     2
# 1933.0     2
# 1946.0     1
# 1957.0     1
# 1956.0     1
# 1965.0     1
# 1969.0     1
# 2010.0     1
# 1942.0     1
# 1944.0     1
# 1936.0     1
# 1937.0     1
# 2008.0     1
# 1958.0     1
# Name: releaseYear, dtype: int64

# %%
df = pd.merge(df, movie_yr, how='inner', on=['mId'],
         left_index=False, right_index=False, sort=True,
         copy=False, indicator=False)
df.head()
# Out:
#   lineId chId mId  chName                                        dialogue  \
# 0  L1045   u0  m0  BIANCA                                    They do not!
# 1   L985   u0  m0  BIANCA                                      I hope so.
# 2   L925   u0  m0  BIANCA                                       Let's go.
# 3   L872   u0  m0  BIANCA  Okay -- you're gonna need to learn how to lie.
# 4   L869   u0  m0  BIANCA                Like my fear of wearing pastels?
#
#                         mName  gender posCredits  releaseYear
# 0  10 things i hate about you       1          4       1999.0
# 1  10 things i hate about you       1          4       1999.0
# 2  10 things i hate about you       1          4       1999.0
# 3  10 things i hate about you       1          4       1999.0
# 4  10 things i hate about you       1          4       1999.0

# %% [markdown]
# **Feature** **Engineering**
#
# Length of lines
#
# Count of lines
#
# One hot encodings for tokens

# %%
df['lineLength'] = df.dialogue.str.len()             ## Length of each line by characters
df['wordCountLine'] = df.dialogue.str.count(' ') + 1 ## Length of each line by words
df.head()
# Out:
#   lineId chId mId  chName                                        dialogue  \
# 0  L1045   u0  m0  BIANCA                                    They do not!
# 1   L985   u0  m0  BIANCA                                      I hope so.
# 2   L925   u0  m0  BIANCA                                       Let's go.
# 3   L872   u0  m0  BIANCA  Okay -- you're gonna need to learn how to lie.
# 4   L869   u0  m0  BIANCA                Like my fear of wearing pastels?
#
#                         mName  gender posCredits  releaseYear  lineLength  \
# 0  10 things i hate about you       1          4       1999.0          12
# 1  10 things i hate about you       1          4       1999.0          10
# 2  10 things i hate about you       1          4       1999.0           9
# 3  10 things i hate about you       1          4       1999.0          46
# 4  10 things i hate about you       1          4       1999.0          32
#
#    wordCountLine
# 0              3
# 1              3
# 2              2
# 3             10
# 4              6

# %% [markdown]
# Next, let's convert the dialogues into clean tokens
#
# Remove Stopwords : because they occur very often, but serve no meaning. e.g. : is,am,are,the.
# Turn all word to smaller cases : I, i -> i
# walk,walks -> walk or geographical,geographic -> geographic
# #Lemmatization

# %%
import nltk
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# True

# %%
import nltk
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
import re

# Download wordnet resource
nltk.download('wordnet')

wordnet_lemmatizer = WordNetLemmatizer()

def clean_dialogue(dialogue):
    # Function to convert a raw review to a string of words
    # The input is a single string (a raw movie review), and
    # the output is a single string (a preprocessed movie review)
    # Source : https://www.kaggle.com/akerlyn/wordcloud-based-on-character
    #
    # 1. Remove HTML
    #
    # 2. Remove non-letters
    letters_only = re.sub("[^a-zA-Z]", " ", dialogue)
    #
    # 3. Convert to lower case, split into individual words
    words = letters_only.lower().split()
    #
    # 4. In Python, searching a set is much faster than searching
    #   a list, so convert the stop words to a set
    stops = set(stopwords.words("english"))

    # 5. Use lemmatization and remove stop words
    meaningful_words = [wordnet_lemmatizer.lemmatize(w) for w in words if not w in stops]
    #
    # 6. Join the words back into one string separated by space,
    # and return the result.
    return " ".join(meaningful_words)

df['cleaned_dialogue'] = df['dialogue'].apply(clean_dialogue)
df[['dialogue', 'cleaned_dialogue']].sample(5)
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
#                                                  dialogue  \
# 39290                             Are you questioning me?
# 119847                                  How's everything?
# 190537  Your mother called.  You shouldn't upset her l...
# 208448  That could take days.  I need to do something ...
# 87760                                  Call an ambulance.
#
#                                      cleaned_dialogue
# 39290                                     questioning
# 119847                                     everything
# 190537                       mother called upset like
# 208448  could take day need something see want u dead
# 87760                                  call ambulance

# %% [markdown]
# **Create training dataset**
# Now, we can aggregate all data for a particular movie character into 1 record.
# We will combine their dialogue tokens from the entire movie, calculate their median dialogue length by characters & words, and count their total no of lines in the movie.

# %%
train = df.groupby(['chId', 'mId', 'chName', 'gender', 'posCredits','releaseYear']). \
            agg({'lineLength' : ['median'],
                 'wordCountLine' : ['median'],
                 'chId' : ['count'],
                 'cleaned_dialogue' : [lambda x : ' '.join(x)]
                })

## Renaming columns by aggregate functions
train.columns = ["_".join(x) for x in train.columns.ravel()]

train.reset_index(inplace=True)
train
# Out:
#        chId  mId   chName  gender posCredits  releaseYear  lineLength_median  \
# 0        u0   m0   BIANCA       1          4       1999.0               34.0
# 1      u100   m6      AMY       1          7       1999.0               23.0
# 2     u1003  m65  RICHARD       0          3       1996.0               24.5
# 3     u1005  m65     SETH       0          2       1996.0               37.0
# 4     u1008  m66     C.O.       0        10+       1997.0               48.0
# ...     ...  ...      ...     ...        ...          ...                ...
# 2946   u980  m63   VICTOR       0          3       1931.0               32.0
# 2947   u983  m64    ALICE       1        10+       2009.0               30.0
# 2948   u985  m64     BILL       0        10+       2009.0               20.0
# 2949   u997  m65    JACOB       0          1       1996.0               36.0
# 2950   u998  m65     KATE       1          4       1996.0               20.0
#
#       wordCountLine_median  chId_count  \
# 0                      7.0          94
# 1                      4.0          31
# 2                      5.0          70
# 3                      8.0         163
# 4                      9.0          33
# ...                    ...         ...
# 2946                   6.0         126
# 2947                   6.0          51
# 2948                   4.0          39
# 2949                   6.0          90
# 2950                   4.5          44
#
#                               cleaned_dialogue_<lambda>
# 0      hope let go okay gonna need learn lie like fe...
# 1     died sleep three day ago paper tom dead  calli...
# 2     asked would said room room serious foolin arou...
# 3     let follow said new jesus christ carlos brothe...
# 4     course uh v p security arrangement generally t...
# ...                                                 ...
# 2946  never said name remembers  kill draw line take...
# 2947  maybe wait mr christy killer still bill bill b...
# 2948  twenty mile crossroad steve back hour thing st...
# 2949  meant son daughter oh daughter bathroom vacati...
# 2950  everybody go home going em swear god father ch...
#
# [2951 rows x 10 columns]

# %% [markdown]
# Let's check some feature distributions by gender

# %%
sns.boxplot(data = train, x = 'gender', y = 'chId_count', hue = 'gender')
# Out:
# <Axes: xlabel='gender', ylabel='chId_count'>

# %%
sns.boxplot(data = train, x = 'gender', y = 'wordCountLine_median', hue = 'gender')
# Out:
# <Axes: xlabel='gender', ylabel='wordCountLine_median'>

# %%
sns.boxplot(data = train, x = 'gender', y = 'lineLength_median', hue = 'gender')
# Out:
# <Axes: xlabel='gender', ylabel='lineLength_median'>

# %%
sns.scatterplot(data = train, x = 'wordCountLine_median', y = 'chId_count', hue = 'gender', alpha = 0.5)
# Out:
# <Axes: xlabel='wordCountLine_median', ylabel='chId_count'>

# %% [markdown]
# **Train test split**
# Now, we can split our data into a training set & a validation set.

# %%
## Separating labels from features
y = train['gender']
X = train.copy()
X.drop('gender', axis=1, inplace=True)

## Removing unnecessary columns
X.drop('chId', axis=1, inplace=True)
X.drop('mId', axis=1, inplace=True)
X.drop('chName', axis=1, inplace=True)
X.head()
# Out:
#   posCredits  releaseYear  lineLength_median  wordCountLine_median  \
# 0          4       1999.0               34.0                   7.0
# 1          7       1999.0               23.0                   4.0
# 2          3       1996.0               24.5                   5.0
# 3          2       1996.0               37.0                   8.0
# 4        10+       1997.0               48.0                   9.0
#
#    chId_count                          cleaned_dialogue_<lambda>
# 0          94   hope let go okay gonna need learn lie like fe...
# 1          31  died sleep three day ago paper tom dead  calli...
# 2          70  asked would said room room serious foolin arou...
# 3         163  let follow said new jesus christ carlos brothe...
# 4          33  course uh v p security arrangement generally t...

# %% [markdown]
# We will pick equal no of records for both male & female characters to avoid any kind of bias due to no of records.

# %%
undersample = RandomUnderSampler(sampling_strategy='majority')
X_under, y_under = undersample.fit_resample(X, y)
y_under.value_counts()
# Out:
# 0    948
# 1    948
# Name: gender, dtype: int64

# %% [markdown]
# We'll also try to keep equal no of male & female records in the train & validation datasets

# %%
X_train, X_val, y_train, y_val = train_test_split(X_under, y_under, test_size=0.2, random_state = 10, stratify=y_under)

y_val.value_counts()
# Out:
# 1    190
# 0    190
# Name: gender, dtype: int64

# %%
X_val.head()
# Out:
#      posCredits  releaseYear  lineLength_median  wordCountLine_median  \
# 1236          2       2001.0               33.0                   6.0
# 924           3       2006.0               29.0                   5.5
# 868         10+       2003.0               28.0                   6.0
# 363           2       1996.0               66.0                  13.0
# 989         10+       2000.0               42.0                   8.0
#
#       chId_count                          cleaned_dialogue_<lambda>
# 1236          60  latitude degree  maybe satellite said three ye...
# 924           42  yes yeah know wanted see make home done alread...
# 868           72  card live break back door open stole car done ...
# 363           44  eliminate like claire fold fold tight satisfie...
# 989           15  okay took trouble come got principle selling o...

# %% [markdown]
# **Pipeline for classifiers**
#
# Since our dataset includes both numerical features & NLP tokens, we'll use a special converter class in our pipeline.

# %%
class Converter(BaseEstimator, TransformerMixin):
    ## Source : https://www.kaggle.com/tylersullivan/classifying-phishing-urls-three-models
    def fit(self, x, y=None):
        return self

    def transform(self, data_frame):
        return data_frame.values.ravel()

# %% [markdown]
# Pipeline for numeric features

# %%
numeric_features = ['lineLength_median', 'wordCountLine_median', 'chId_count', 'releaseYear']

numeric_transformer = Pipeline(steps=[('scaler', MinMaxScaler())])

# %% [markdown]
# Pipeline for tokens dereived from dialogues

# %%
categorical_features = ['posCredits']
categorical_transformer = Pipeline(steps=[
    ('onehot', OneHotEncoder(handle_unknown='ignore'))])

# %%
vectorizer_features = ['cleaned_dialogue_<lambda>']
vectorizer_transformer = Pipeline(steps=[
    ('con', Converter()),
    ('tf', TfidfVectorizer())])

# %% [markdown]
# Now, we can combine preprocessing pipelines with the classifers. We will try 4 basic models:
#
#
# Linear Support Vector Classifier
#
# Logistic Regression Classifier
#
# Naive Bayes Classifier
#
# Random Forest Clasifier

# %%
preprocessor = ColumnTransformer(
    transformers=[
        ('num', numeric_transformer, numeric_features),
        ('cat', categorical_transformer, categorical_features),
        ('vec', vectorizer_transformer, vectorizer_features)
    ])

svc_clf = Pipeline(steps=[('preprocessor', preprocessor),
                      ('classifier', CalibratedClassifierCV(LinearSVC()))])  ## LinearSVC has no predict_proba method

log_clf = Pipeline(steps=[('preprocessor', preprocessor),
                      ('classifier', LogisticRegression())])

nb_clf = Pipeline(steps=[('preprocessor', preprocessor),
                      ('classifier', MultinomialNB())])

rf_clf = Pipeline(steps=[('preprocessor', preprocessor),
                      ('classifier', RandomForestClassifier(n_estimators=120, min_samples_leaf=10,
                                                            max_features=0.7, n_jobs=-1, oob_score=True))])

# %% [markdown]
# Fitting the preprocessing & classifier pipelines on training data

# %%
svc_clf.fit(X_train, y_train)
log_clf.fit(X_train, y_train)
nb_clf.fit(X_train, y_train)
rf_clf.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('num',
#                                                   Pipeline(steps=[('scaler',
#                                                                    MinMaxScaler())]),
#                                                   ['lineLength_median',
#                                                    'wordCountLine_median',
#                                                    'chId_count',
#                                                    'releaseYear']),
#                                                  ('cat',
#                                                   Pipeline(steps=[('onehot',
#                                                                    OneHotEncoder(handle_unknown='ignore'))]),
#                                                   ['posCredits']),
#                                                  ('vec',
#                                                   Pipeline(steps=[('con',
#                                                                    Converter()),
#                                                                   ('tf',
#                                                                    TfidfVectorizer())]),
#                                                   ['cleaned_dialogue_<lambda>'])])),
#                 ('classifier',
#                  RandomForestClassifier(max_features=0.7, min_samples_leaf=10,
#                                         n_estimators=120, n_jobs=-1,
#                                         oob_score=True))])

# %% [markdown]
# Check results on the validation set

# %%
def results(name: str, model: BaseEstimator) -> None:
    '''
    Custom function to check model performance on validation set
    '''
    preds = model.predict(X_val)

    print(name + " score: %.3f" % model.score(X_val, y_val))
    print(classification_report(y_val, preds))
    labels = ['Male', 'Female']

    conf_matrix = confusion_matrix(y_val, preds)
    plt.figure(figsize= (10,6))
    sns.heatmap(conf_matrix, xticklabels=labels, yticklabels=labels, annot=True, fmt="d", cmap='Blues')
    plt.title("Confusion Matrix for " + name)
    plt.ylabel('True Class')
    plt.xlabel('Predicted Class')

# %%
results("SVC" , svc_clf)
results("Logistic Regression" , log_clf)
results("Naive Bayes" , nb_clf)
results("Random Forest" , rf_clf)
# Out:
# SVC score: 0.726
#               precision    recall  f1-score   support
#
#            0       0.73      0.71      0.72       190
#            1       0.72      0.74      0.73       190
#
#     accuracy                           0.73       380
#    macro avg       0.73      0.73      0.73       380
# weighted avg       0.73      0.73      0.73       380
#
# Logistic Regression score: 0.724
#               precision    recall  f1-score   support
#
#            0       0.73      0.72      0.72       190
#            1       0.72      0.73      0.73       190
#
#     accuracy                           0.72       380
#    macro avg       0.72      0.72      0.72       380
# weighted avg       0.72      0.72      0.72       380
#
# Naive Bayes score: 0.697
#               precision    recall  f1-score   support
#
#            0       0.71      0.67      0.69       190
#            1       0.69      0.72      0.70       190
#
#     accuracy                           0.70       380
#    macro avg       0.70      0.70      0.70       380
# weighted avg       0.70      0.70      0.70       380
#
# Random Forest score: 0.700
#               precision    recall  f1-score   support
#
#            0       0.70      0.70      0.70       190
#            1       0.70      0.70      0.70       190
#
#     accuracy                           0.70       380
#    macro avg       0.70      0.70      0.70       380
# weighted avg       0.70      0.70      0.70       380

# %% [markdown]
# We are getting accuracy in the range of 70-75% for most of the models, which is pretty good. Some possible ways to improve this performance could be:
#
#
# using bi-grams or tri-grams for dialogue tokens
#
# Trying out feed forward neural networks, LSTM or CNN
#
# additional feature engineering related to context of dialogues in the movie
#
#
# Still, our current classifier performance is good enough to understand that there is indeed a gender bias in the characters of Hollywood movies which our models are capturing fairly well.
#
#
# Let's explore what features contribute the most to our classifiers through some model explainability techniques.

# %% [markdown]
# ###Feature importance

# %% [markdown]
# Creating a list of all features including numeric & vectorised features

# %%
# Assuming 'tf' is your TfidfVectorizer
tfidf_vectorizer = svc_clf.named_steps['preprocessor'].named_transformers_['vec'].named_steps['tf']

# Get feature names from the vocabulary of TfidfVectorizer
vectorizer_feature_names = tfidf_vectorizer.get_feature_names_out()

# Continue with the rest of your code
onehot_columns = list(svc_clf.named_steps['preprocessor'].named_transformers_['cat'].named_steps['onehot'].get_feature_names_out(input_features=categorical_features))
numeric_features_list = list(numeric_features)
numeric_features_list.extend(onehot_columns)
numeric_features_list.extend(vectorizer_feature_names)

# %% [markdown]
# Feature importance for Logistic Regression

# %%
# !pip install eli5
import eli5
# Out:
# Requirement already satisfied: eli5 in /usr/local/lib/python3.10/dist-packages (0.13.0)
# Requirement already satisfied: attrs>17.1.0 in /usr/local/lib/python3.10/dist-packages (from eli5) (23.1.0)
# Requirement already satisfied: jinja2>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from eli5) (3.1.2)
# Requirement already satisfied: numpy>=1.9.0 in /usr/local/lib/python3.10/dist-packages (from eli5) (1.23.5)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from eli5) (1.11.3)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from eli5) (1.16.0)
# Requirement already satisfied: scikit-learn>=0.20 in /usr/local/lib/python3.10/dist-packages (from eli5) (1.2.2)
# Requirement already satisfied: graphviz in /usr/local/lib/python3.10/dist-packages (from eli5) (0.20.1)
# Requirement already satisfied: tabulate>=0.7.7 in /usr/local/lib/python3.10/dist-packages (from eli5) (0.9.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2>=3.0.0->eli5) (2.1.3)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.20->eli5) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.20->eli5) (3.2.0)

# %%
lr_weights = eli5.explain_weights_df(log_clf.named_steps['classifier'], top=30, feature_names=numeric_features_list)
lr_weights.head(15)
# Out:
#     target  feature    weight
# 0        1       oh  3.038150
# 1        1   really  1.386061
# 2        1     love  1.337705
# 3        1     like  1.252242
# 4        1     said  1.070437
# 5        1    think  1.024068
# 6        1  thought  1.021440
# 7        1    daddy  1.016385
# 8        1       hi  0.952463
# 9        1     want  0.912165
# 10       1   father  0.903832
# 11       1    child  0.890072
# 12       1   school  0.879778
# 13       1    silly  0.837104
# 14       1      yes  0.831391

# %%
lr_weights
# Out:
#     target            feature    weight
# 0        1                 oh  3.038150
# 1        1             really  1.386061
# 2        1               love  1.337705
# 3        1               like  1.252242
# 4        1               said  1.070437
# 5        1              think  1.024068
# 6        1            thought  1.021440
# 7        1              daddy  1.016385
# 8        1                 hi  0.952463
# 9        1               want  0.912165
# 10       1             father  0.903832
# 11       1              child  0.890072
# 12       1             school  0.879778
# 13       1              silly  0.837104
# 14       1                yes  0.831391
# 15       1            captain -0.848259
# 16       1                 as -0.851538
# 17       1               shit -0.857532
# 18       1                 ah -0.863338
# 19       1               good -0.875168
# 20       1  lineLength_median -0.920613
# 21       1                sir -0.925599
# 22       1             fuckin -0.966090
# 23       1                 ya -1.004051
# 24       1                got -1.111285
# 25       1         chId_count -1.115410
# 26       1              gotta -1.119391
# 27       1               hell -1.182761
# 28       1                hey -1.216349
# 29       1                man -1.533689

# %%
lr_weights.tail(14)
# Out:
#     target            feature    weight
# 16       1                 as -0.851538
# 17       1               shit -0.857532
# 18       1                 ah -0.863338
# 19       1               good -0.875168
# 20       1  lineLength_median -0.920613
# 21       1                sir -0.925599
# 22       1             fuckin -0.966090
# 23       1                 ya -1.004051
# 24       1                got -1.111285
# 25       1         chId_count -1.115410
# 26       1              gotta -1.119391
# 27       1               hell -1.182761
# 28       1                hey -1.216349
# 29       1                man -1.533689

# %% [markdown]
# We see that dialogue keywords like "oh", "love", "like", "darling", "want", "honey" are strong indicators that the character is a female, while keywords like "sir", "man", "hell", "fuckin", "gotta" & "yeah" are usually found in the dialogues of male characters!

# %% [markdown]
# Let's also try to visualize a single decision tree
# We can training a single decision tree using the Random Forest Classifier.

# %%
m = RandomForestClassifier(n_estimators=1, min_samples_leaf=5, max_depth = 3,
                           oob_score=True, random_state = np.random.seed(123))
dt_clf = Pipeline(steps=[('preprocessor', preprocessor),
                         ('classifier', m)])

dt_clf.fit(X_train, y_train)
results("Decision Tree Classifier", dt_clf)
# Out:
# Decision Tree Classifier score: 0.534
#               precision    recall  f1-score   support
#
#            0       0.52      0.83      0.64       190
#            1       0.58      0.24      0.34       190
#
#     accuracy                           0.53       380
#    macro avg       0.55      0.53      0.49       380
# weighted avg       0.55      0.53      0.49       380

# %% [markdown]
# While a single decision is a poor classifier with accuracy barely more than 50%, we see that bagging enough of such weak classifiers to form a Random Forest model helps us improve the model performance drastically! Let's look at how the splits are made for a single decision tree.

# %%
def draw_tree(t, df, size=10, ratio=0.6, precision=0):
    """
    Draws a representation of a decition tree in IPython from fastai v0.7
    """
    s=export_graphviz(t, out_file=None, feature_names=numeric_features_list, filled=True,
                      special_characters=True, rotate=True, precision=precision,
                      proportion=True, class_names = ["male", "female"], impurity = False)
    IPython.display.display(graphviz.Source(re.sub('Tree {',
       f'Tree {{ size={size}; ratio={ratio}', s)))

draw_tree(m.estimators_[0], X_train, precision=2)

# %% [markdown]
# Here the blue colored nodes indicate their majority class is "female" while the orange colored nodes have a majority of "male" labels. The decision tree starts with a mixed sample, but the leaves of the tree are biased towards one class or the other. Most splits seem to be happening using dialogue tokens.

# %% [markdown]
# Feature importance for the Random Forest model

# %%
eli5.explain_weights_df(rf_clf.named_steps['classifier'], top=30, feature_names=numeric_features_list)
# Out:
#                  feature    weight       std
# 0                     oh  0.076316  0.034380
# 1      lineLength_median  0.025600  0.023346
# 2                    man  0.020763  0.023069
# 3                     em  0.019787  0.029321
# 4                   love  0.018259  0.022898
# 5                    got  0.014604  0.018867
# 6                   said  0.013152  0.018233
# 7                 really  0.013044  0.018180
# 8                thought  0.012759  0.016189
# 9                   like  0.010475  0.013592
# 10                  want  0.010042  0.013773
# 11                  good  0.009584  0.014077
# 12                 think  0.009186  0.013203
# 13                   see  0.009163  0.011165
# 14                    as  0.008947  0.021147
# 15                  hell  0.008803  0.017551
# 16                   hey  0.008438  0.016347
# 17                  give  0.008432  0.017417
# 18                  look  0.008400  0.012595
# 19                  come  0.008366  0.010986
# 20                  know  0.008366  0.011578
# 21           releaseYear  0.007758  0.009977
# 22                 going  0.007685  0.011101
# 23            chId_count  0.007558  0.011491
# 24                  shit  0.007149  0.015416
# 25  wordCountLine_median  0.006938  0.014020
# 26                   one  0.006843  0.011748
# 27                   get  0.006420  0.010392
# 28                    go  0.006342  0.009516
# 29                 right  0.005949  0.009958

# %% [markdown]
# We see that the median length of a dialogue, total no of lines (chId_count) & position in the post credits in a movie are important features along with the tokens extracted from the character's dialogues for the Random Forest model!
